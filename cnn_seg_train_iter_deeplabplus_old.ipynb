# %%
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
#os.environ['LD_LIBRARY_PATH']= '$LD_LIBRARY_PATH:/usr/local/cuda/extras/CUPTI/lib64'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prep lists of input files

# %%
from glob import glob
import re
import pandas as pd
from random import sample, seed

# %%
encoder_list = ['resnet34']
avail_suffix = ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']

# %%
# set working directory
os.chdir('/project/cper_neon_aop/cper_pdog_uas')

# set directories for training data and labels
DATA_FOLDER = './cnn_train_images/{}_{}.tif'
LABEL_FOLDER = './cnn_train_labels/{}_labels.tif'

# %%
# read in csvs with training information
df_tiles = pd.read_csv('train_tiles/train_bboxes_all_assigned.csv')
df_polys = pd.read_csv('train_polys/train_polys_all.csv')

# %%
# get all ids to be used
label_files = glob(LABEL_FOLDER.replace('{}', '*'))
all_ids = [re.sub('_labels.tif', '', os.path.basename(f)) for f in label_files]
all_tiles = list(set(['_'.join(y.split('_')[2:]) for y in all_ids]))

# %%
# separate training and test data and get paths to files
all_files = glob(DATA_FOLDER.replace('{}', '*'))
all_train_tiles = [x for x in df_tiles.apply(lambda x: '_'.join([x.Pasture, x.Tile]) if x.Train == 1 else '', axis=1) if x != '' and x in all_tiles]
test_tiles = list(set(all_tiles) - set(all_train_tiles))

all_train_ids = [x for x in all_ids if '_'.join(x.split('_')[-3:]) in all_train_tiles]
test_ids = list(set(all_ids) - set(all_train_ids))

seed(321)
valid_ids = sample(all_train_ids, int(np.ceil(len(all_train_ids)*0.3)))
train_ids = list(set(all_train_ids) - set(valid_ids))

train_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in train_ids]
valid_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in valid_ids]
test_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in test_ids]

# %%
tile_ids = df_tiles[(df_tiles['trainer'] != 'Nick') &
                    (df_tiles['Digitize'] == 1)].apply(lambda x: '_'.join([x.Pasture, x.Tile]), axis=1)
#all_tiles#
[x for x in all_tiles if x not in tile_ids.to_list()]
# Out:
# []

# %%
[x for x in tile_ids.to_list() if x not in all_tiles]
# Out:
# []

# %% [markdown]
# ### Dataloader
# Writing helper class for data extraction, tranformation and preprocessing

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset
from skimage import io

# %%
class Dataset(BaseDataset):
    """Read images, apply augmentation and preprocessing transformations.
    
    Args:
        ids (list): list of unique ids for all images
        images_path (str): path to data images
        masks_path (str): path to label masks
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    
    CLASSES = ['other', 'burrow']
    
    def __init__(
            self, 
            ids,
            suffix_list,
            images_path,
            masks_path, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
            suffix_dict = {
        'rgb': {'channels': 3,
                'dtype': 'uint8'},
        'tpi': {'channels': 1,
                'dtype': 'float32'},
        'dsm': {'channels': 1,
                'dtype': 'float32'},
        'shade': {'channels': 1,
                  'dtype': 'float32'},
        'ndvi': {'channels': 1,
                  'dtype': 'float32'}
    }
    ):
        # get IDs as attribute
        self.ids = ids
        
        # get suffix info
        self.suffix_dict = suffix_dict
        
        # get list of suffixes as attribute
        self.suffix_list = suffix_list
        
        # List of files
        self.images_fps = []
        self.masks_fps = [masks_path.format(id) for id in ids]
        for id in ids:
            self.images_fps.append({s: images_path.format(id, s) for s in suffix_list})
            
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image_list = []
        self.image_dict = {}
        for s in self.suffix_list:
            image_s = np.asarray(io.imread(self.images_fps[i][s]), dtype=self.suffix_dict[s]['dtype'])
            if len(image_s.shape) == 2:
                image_s = np.expand_dims(image_s, axis=-1)
            image_list.append(image_s)
            self.image_dict[s] = image_s
        if len(image_list) == 1:
            image = image_list[0]
        else:
            image = np.concatenate(image_list, axis=-1)
        mask = np.asarray(io.imread(self.masks_fps[i]), dtype='float32')
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1)#.astype('float32')
        #print('fetched: ', self.ids[i])
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        else:
            image = torch.from_numpy(image.transpose(2, 0, 1).astype('float32'))
            mask = torch.from_numpy(mask.transpose(2, 0, 1).astype('float32'))
        return image, mask
        
    def __len__(self):
        return len(self.ids)

# %% [markdown]
# ### Augmentations

# %%
import albumentations as albu
import random

# %%
def get_training_augmentation():
    win_size = 32 * random.randint(7, 10)
    train_transform = [

        albu.HorizontalFlip(p=0.5),
        albu.VerticalFlip(p=0.5),

        #albu.ShiftScaleRotate(scale_limit=0.0, rotate_limit=45, shift_limit=0.1, p=1, border_mode=0),

        #albu.PadIfNeeded(min_height=win_size, min_width=win_size, always_apply=True, border_mode=4),
        albu.RandomCrop(height=win_size, width=win_size, always_apply=True),

        #albu.GaussNoise(p=0.2, var_limit=1.0),
        #albu.Perspective(p=0.5),

        #albu.OneOf(
        #    [
        #        #albu.CLAHE(p=1), # required int8 images
        #        albu.RandomBrightnessContrast(p=1),
        #        #albu.RandomGamma(p=1),
        #        #albu.HueSaturationValue(p=1),
        #    ],
        #    p=0.9,
        #),

        albu.OneOf(
            [
                albu.Sharpen(p=1),
                albu.Blur(blur_limit=(3, 7), p=1),
                albu.MotionBlur(blur_limit=(3, 7), p=1),
            ],
            p=0.9,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.PadIfNeeded(384, 480)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %% [markdown]
# ### Create and train model

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils
import torch.nn as nn
import gc

# %%
ENCODER = 'resnet34'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['burrow']
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #'cuda'# 'cpu'# 
USE_PARALLEL = True

# %%
import itertools
#list(itertools.combinations(avail_suffix, len(avail_suffix)))
suffix_combinations = list()
for n in range(1, len(avail_suffix) + 1):
    suffix_combinations += list(itertools.combinations(avail_suffix, n))

# %%
outDIR = './cnn_results_deeplabplus/'
if not os.path.exists(outDIR):
    os.mkdir(outDIR)

# %%
for suffix_sub in suffix_combinations:
    suffix_list = list(suffix_sub)
    print('\n\n----------------------------------------------------------')
    print(suffix_list)
    if os.path.exists(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt'):
        print('skipping - already trained.')
        continue
    else:
        train_dataset = Dataset(
            train_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            augmentation=get_training_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)

        valid_dataset = Dataset(
            valid_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            #augmentation=get_validation_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)


        train_loader = DataLoader(train_dataset, batch_size=6, shuffle=False,
                                  drop_last=True, num_workers=6, pin_memory=False)
        valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=6, pin_memory=False)

        # create segmentation model with pretrained encoder
        model = smp.DeepLabV3Plus(
            encoder_name=ENCODER, 
            encoder_weights=ENCODER_WEIGHTS, 
            classes=len(CLASSES), 
            activation=ACTIVATION,
            in_channels=train_dataset[0][0].shape[0],
        )
        
        if USE_PARALLEL:
            model = nn.DataParallel(model)

        preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

        # Dice/F1 score - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
        # IoU/Jaccard score - https://en.wikipedia.org/wiki/Jaccard_index

        loss = smp.losses.MCCLoss()
        loss.__name__ = 'mccloss'
        metrics = [
            utils.metrics.IoU(threshold=0.5),
            utils.metrics.Accuracy(threshold=0.5),
            utils.metrics.Precision(threshold=0.5),
            utils.metrics.Recall(threshold=0.5),
            utils.metrics.Fscore(threshold=0.5)
        ]

        optimizer = torch.optim.Adam([ 
            dict(params=model.parameters(), lr=0.0001),
        ])

        # create epoch runners 
        # it is a simple loop of iterating over dataloader`s samples
        train_epoch = utils.train.TrainEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            optimizer=optimizer,
            device=DEVICE,
            verbose=True,
        )

        valid_epoch = utils.train.ValidEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            device=DEVICE,
            verbose=True,
        )

        # train model for up to 60 epochs

        max_score = 0
        no_improve = 0

        for i in range(1, 61):

            print('\nEpoch: {}'.format(i))
            train_logs = train_epoch.run(train_loader)
            valid_logs = valid_epoch.run(valid_loader)

            # do something (save model, change lr, etc.)
            if max_score < valid_logs['fscore']:
                max_score = valid_logs['fscore']
                max_score_train = train_logs['fscore']
                torch.save(model, outDIR + 'best_model_' + '_'.join(suffix_list) + '.pth')
                valid_logs['best_epoch'] = i
                best_valid_logs = valid_logs.copy()
                print('Model saved!')
                no_improve = 0
            else:
                no_improve += 1
                print('No improvement in ' + str(no_improve) + ' epochs. Model not saved.')

            if i%15 == 0:
                no_improve = 0
                optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr'] * 0.1
                print('Decrease decoder learning rate by factor of 10')

            if i > 15:
                if no_improve >= 5:
                    if (train_logs['fscore'] - max_score_train) < 0.05:
                        print('More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
                    elif no_improve == 15:
                        print('15 epochs without validation improvement while learning rate <= 1e-5...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
            if i == 60:
                with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))

        del model, train_epoch, valid_epoch
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ----------------------------------------------------------
# ['rgb']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:09<00:00,  6.11it/s, mccloss - 0.8923, iou_score - 0.05661, accuracy - 0.5891, precision - 0.05677, recall - 0.9694, fscore - 0.103]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.36it/s, mccloss - 0.9303, iou_score - 0.1319, accuracy - 0.8595, precision - 0.1417, recall - 0.9028, fscore - 0.1708]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:05<00:00, 11.02it/s, mccloss - 0.8225, iou_score - 0.1285, accuracy - 0.8753, precision - 0.1299, recall - 0.9259, fscore - 0.2163]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.61it/s, mccloss - 0.9044, iou_score - 0.3837, accuracy - 0.9509, precision - 0.4608, recall - 0.8741, fscore - 0.4291]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:04<00:00, 11.26it/s, mccloss - 0.7613, iou_score - 0.2061, accuracy - 0.9313, precision - 0.2118, recall - 0.9132, fscore - 0.3211]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.82it/s, mccloss - 0.8718, iou_score - 0.3769, accuracy - 0.9556, precision - 0.408, recall - 0.9089, fscore - 0.4311]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:05<00:00, 10.88it/s, mccloss - 0.7048, iou_score - 0.2485, accuracy - 0.9489, precision - 0.2628, recall - 0.9085, fscore - 0.3747]
# valid: 100%|██████████| 144/144 [00:03<00:00, 41.83it/s, mccloss - 0.8615, iou_score - 0.6371, accuracy - 0.983, precision - 0.7725, recall - 0.8347, fscore - 0.6845]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:05<00:00, 10.46it/s, mccloss - 0.657, iou_score - 0.2828, accuracy - 0.9591, precision - 0.3022, recall - 0.8752, fscore - 0.4125]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.45it/s, mccloss - 0.8119, iou_score - 0.4628, accuracy - 0.9754, precision - 0.5362, recall - 0.8729, fscore - 0.5148]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:05<00:00, 10.50it/s, mccloss - 0.6, iou_score - 0.3335, accuracy - 0.9709, precision - 0.3731, recall - 0.8446, fscore - 0.4737]
# valid: 100%|██████████| 144/144 [00:03<00:00, 41.49it/s, mccloss - 0.8512, iou_score - 0.628, accuracy - 0.987, precision - 0.8598, recall - 0.7554, fscore - 0.6653]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:06<00:00,  9.00it/s, mccloss - 0.5701, iou_score - 0.3387, accuracy - 0.9729, precision - 0.386, recall - 0.8215, fscore - 0.477]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.85it/s, mccloss - 0.8265, iou_score - 0.6649, accuracy - 0.9879, precision - 0.8471, recall - 0.7835, fscore - 0.7059]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:06<00:00,  9.23it/s, mccloss - 0.5162, iou_score - 0.3809, accuracy - 0.9775, precision - 0.4447, recall - 0.815, fscore - 0.5229]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.18it/s, mccloss - 0.8021, iou_score - 0.6935, accuracy - 0.9895, precision - 0.8645, recall - 0.7863, fscore - 0.7348]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:06<00:00,  8.80it/s, mccloss - 0.492, iou_score - 0.3878, accuracy - 0.9791, precision - 0.4582, recall - 0.8155, fscore - 0.5294]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.85it/s, mccloss - 0.7763, iou_score - 0.5976, accuracy - 0.9861, precision - 0.6975, recall - 0.8356, fscore - 0.6442]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:07<00:00,  7.45it/s, mccloss - 0.4381, iou_score - 0.4413, accuracy - 0.984, precision - 0.522, recall - 0.8234, fscore - 0.5889]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.76it/s, mccloss - 0.8029, iou_score - 0.7036, accuracy - 0.9902, precision - 0.9285, recall - 0.755, fscore - 0.7424]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:07<00:00,  7.62it/s, mccloss - 0.4133, iou_score - 0.4912, accuracy - 0.9872, precision - 0.6332, recall - 0.7633, fscore - 0.6314]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.29it/s, mccloss - 0.794, iou_score - 0.4197, accuracy - 0.9713, precision - 0.4864, recall - 0.8716, fscore - 0.4702]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:07<00:00,  7.99it/s, mccloss - 0.4707, iou_score - 0.3825, accuracy - 0.9774, precision - 0.4479, recall - 0.7966, fscore - 0.5218]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.20it/s, mccloss - 0.7864, iou_score - 0.6962, accuracy - 0.9898, precision - 0.8627, recall - 0.7838, fscore - 0.7377]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:07<00:00,  7.57it/s, mccloss - 0.4178, iou_score - 0.4354, accuracy - 0.9839, precision - 0.5206, recall - 0.8026, fscore - 0.5815]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.35it/s, mccloss - 0.777, iou_score - 0.731, accuracy - 0.9904, precision - 0.9, recall - 0.7899, fscore - 0.7738]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:06<00:00,  8.01it/s, mccloss - 0.3825, iou_score - 0.4907, accuracy - 0.9872, precision - 0.6184, recall - 0.7619, fscore - 0.6354]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.51it/s, mccloss - 0.8099, iou_score - 0.6843, accuracy - 0.9898, precision - 0.9262, recall - 0.7403, fscore - 0.724]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:07<00:00,  7.67it/s, mccloss - 0.3712, iou_score - 0.4921, accuracy - 0.9864, precision - 0.6183, recall - 0.7932, fscore - 0.6333]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.26it/s, mccloss - 0.8127, iou_score - 0.6853, accuracy - 0.9899, precision - 0.9413, recall - 0.7287, fscore - 0.7247]
# No improvement in 2 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:07<00:00,  7.37it/s, mccloss - 0.3631, iou_score - 0.5048, accuracy - 0.9889, precision - 0.6608, recall - 0.7286, fscore - 0.6486]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.81it/s, mccloss - 0.7833, iou_score - 0.7055, accuracy - 0.9908, precision - 0.9153, recall - 0.7771, fscore - 0.7451]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:07<00:00,  7.70it/s, mccloss - 0.3322, iou_score - 0.5563, accuracy - 0.99, precision - 0.723, recall - 0.753, fscore - 0.7008]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.10it/s, mccloss - 0.7792, iou_score - 0.7026, accuracy - 0.9906, precision - 0.892, recall - 0.7928, fscore - 0.7426]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:07<00:00,  7.48it/s, mccloss - 0.3392, iou_score - 0.5247, accuracy - 0.9891, precision - 0.6707, recall - 0.7788, fscore - 0.6688]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.08it/s, mccloss - 0.7788, iou_score - 0.695, accuracy - 0.9898, precision - 0.8688, recall - 0.8013, fscore - 0.7353]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:07<00:00,  7.93it/s, mccloss - 0.3004, iou_score - 0.5772, accuracy - 0.9905, precision - 0.7041, recall - 0.811, fscore - 0.7139]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.10it/s, mccloss - 0.7846, iou_score - 0.7036, accuracy - 0.9907, precision - 0.9098, recall - 0.7787, fscore - 0.743]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:07<00:00,  7.43it/s, mccloss - 0.3336, iou_score - 0.5502, accuracy - 0.9907, precision - 0.7087, recall - 0.7476, fscore - 0.6821]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.32it/s, mccloss - 0.788, iou_score - 0.7004, accuracy - 0.9903, precision - 0.9064, recall - 0.7793, fscore - 0.7404]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:07<00:00,  7.34it/s, mccloss - 0.2954, iou_score - 0.5921, accuracy - 0.9912, precision - 0.7317, recall - 0.7957, fscore - 0.7246]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.32it/s, mccloss - 0.7811, iou_score - 0.6925, accuracy - 0.9899, precision - 0.8698, recall - 0.7976, fscore - 0.733]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:07<00:00,  7.59it/s, mccloss - 0.3194, iou_score - 0.5638, accuracy - 0.9905, precision - 0.6981, recall - 0.772, fscore - 0.694]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.21it/s, mccloss - 0.7719, iou_score - 0.6852, accuracy - 0.9889, precision - 0.8366, recall - 0.8192, fscore - 0.7265]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:06<00:00,  8.01it/s, mccloss - 0.3059, iou_score - 0.5692, accuracy - 0.9904, precision - 0.6819, recall - 0.8168, fscore - 0.706]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.57it/s, mccloss - 0.7731, iou_score - 0.6929, accuracy - 0.9907, precision - 0.8825, recall - 0.7942, fscore - 0.7348]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:07<00:00,  7.59it/s, mccloss - 0.29, iou_score - 0.5926, accuracy - 0.991, precision - 0.7285, recall - 0.798, fscore - 0.7269]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.35it/s, mccloss - 0.7773, iou_score - 0.6797, accuracy - 0.9899, precision - 0.8617, recall - 0.7942, fscore - 0.7226]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:07<00:00,  7.43it/s, mccloss - 0.2907, iou_score - 0.5965, accuracy - 0.9914, precision - 0.7203, recall - 0.7997, fscore - 0.7241]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.12it/s, mccloss - 0.7747, iou_score - 0.6752, accuracy - 0.99, precision - 0.8564, recall - 0.795, fscore - 0.7178]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:07<00:00,  7.95it/s, mccloss - 0.2796, iou_score - 0.6093, accuracy - 0.9915, precision - 0.7484, recall - 0.7952, fscore - 0.7401]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.21it/s, mccloss - 0.7728, iou_score - 0.6917, accuracy - 0.9907, precision - 0.8807, recall - 0.7943, fscore - 0.7338]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 27
# train: 100%|██████████| 56/56 [00:07<00:00,  7.60it/s, mccloss - 0.2736, iou_score - 0.6114, accuracy - 0.9919, precision - 0.7304, recall - 0.8243, fscore - 0.7409]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.10it/s, mccloss - 0.7791, iou_score - 0.7061, accuracy - 0.9909, precision - 0.9099, recall - 0.7803, fscore - 0.7486]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 28
# train: 100%|██████████| 56/56 [00:07<00:00,  7.70it/s, mccloss - 0.2694, iou_score - 0.6189, accuracy - 0.992, precision - 0.7696, recall - 0.7941, fscore - 0.7495]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.80it/s, mccloss - 0.7806, iou_score - 0.691, accuracy - 0.9906, precision - 0.889, recall - 0.7839, fscore - 0.7326]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 29
# train: 100%|██████████| 56/56 [00:07<00:00,  7.19it/s, mccloss - 0.2662, iou_score - 0.6473, accuracy - 0.9923, precision - 0.7781, recall - 0.8064, fscore - 0.7681]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.81it/s, mccloss - 0.7827, iou_score - 0.6956, accuracy - 0.9905, precision - 0.8962, recall - 0.7816, fscore - 0.7369]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 30
# train: 100%|██████████| 56/56 [00:05<00:00, 10.68it/s, mccloss - 0.2665, iou_score - 0.6181, accuracy - 0.992, precision - 0.7549, recall - 0.8113, fscore - 0.748]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.13it/s, mccloss - 0.7771, iou_score - 0.6863, accuracy - 0.9905, precision - 0.8841, recall - 0.7847, fscore - 0.7281]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 31
# train: 100%|██████████| 56/56 [00:05<00:00, 10.59it/s, mccloss - 0.2622, iou_score - 0.6438, accuracy - 0.9923, precision - 0.7799, recall - 0.8098, fscore - 0.7719]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.69it/s, mccloss - 0.7806, iou_score - 0.6832, accuracy - 0.9906, precision - 0.8907, recall - 0.7773, fscore - 0.7241]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 32
# train: 100%|██████████| 56/56 [00:05<00:00, 11.16it/s, mccloss - 0.2686, iou_score - 0.6174, accuracy - 0.992, precision - 0.742, recall - 0.821, fscore - 0.7439]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.47it/s, mccloss - 0.7795, iou_score - 0.6845, accuracy - 0.9906, precision - 0.8888, recall - 0.779, fscore - 0.7264]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 33
# train: 100%|██████████| 56/56 [00:05<00:00, 10.72it/s, mccloss - 0.2709, iou_score - 0.6185, accuracy - 0.9923, precision - 0.7722, recall - 0.784, fscore - 0.7451]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.17it/s, mccloss - 0.7784, iou_score - 0.6915, accuracy - 0.9907, precision - 0.8974, recall - 0.7782, fscore - 0.7333]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 34
# train: 100%|██████████| 56/56 [00:04<00:00, 11.26it/s, mccloss - 0.2585, iou_score - 0.633, accuracy - 0.9924, precision - 0.7669, recall - 0.8189, fscore - 0.7595]
# valid: 100%|██████████| 144/144 [00:03<00:00, 43.27it/s, mccloss - 0.772, iou_score - 0.6832, accuracy - 0.9903, precision - 0.8737, recall - 0.7914, fscore - 0.7261]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 35
# train: 100%|██████████| 56/56 [00:05<00:00, 10.92it/s, mccloss - 0.2535, iou_score - 0.6386, accuracy - 0.9926, precision - 0.7584, recall - 0.8303, fscore - 0.7638]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.75it/s, mccloss - 0.7734, iou_score - 0.6898, accuracy - 0.9907, precision - 0.8851, recall - 0.7874, fscore - 0.7324]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 36
# train: 100%|██████████| 56/56 [00:05<00:00, 10.55it/s, mccloss - 0.2583, iou_score - 0.6311, accuracy - 0.9925, precision - 0.7705, recall - 0.8099, fscore - 0.7572]
# valid: 100%|██████████| 144/144 [00:03<00:00, 41.66it/s, mccloss - 0.7741, iou_score - 0.6806, accuracy - 0.9905, precision - 0.8779, recall - 0.7852, fscore - 0.7232]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 37
# train: 100%|██████████| 56/56 [00:05<00:00, 10.96it/s, mccloss - 0.2603, iou_score - 0.627, accuracy - 0.9922, precision - 0.7504, recall - 0.8284, fscore - 0.754]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.82it/s, mccloss - 0.7773, iou_score - 0.6782, accuracy - 0.9906, precision - 0.8809, recall - 0.7801, fscore - 0.7201]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 38
# train: 100%|██████████| 56/56 [00:06<00:00,  8.97it/s, mccloss - 0.2655, iou_score - 0.6386, accuracy - 0.992, precision - 0.7759, recall - 0.8067, fscore - 0.7669]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.29it/s, mccloss - 0.7794, iou_score - 0.6842, accuracy - 0.9905, precision - 0.8846, recall - 0.782, fscore - 0.7253]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 39
# train: 100%|██████████| 56/56 [00:05<00:00,  9.74it/s, mccloss - 0.2533, iou_score - 0.6424, accuracy - 0.9926, precision - 0.7635, recall - 0.8255, fscore - 0.7638]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.76it/s, mccloss - 0.7775, iou_score - 0.6852, accuracy - 0.9906, precision - 0.8871, recall - 0.7811, fscore - 0.7269]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 40
# train: 100%|██████████| 56/56 [00:06<00:00,  8.48it/s, mccloss - 0.2544, iou_score - 0.6379, accuracy - 0.9926, precision - 0.7692, recall - 0.8175, fscore - 0.7625]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.28it/s, mccloss - 0.7783, iou_score - 0.6781, accuracy - 0.9905, precision - 0.877, recall - 0.783, fscore - 0.7197]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 41
# train: 100%|██████████| 56/56 [00:07<00:00,  7.98it/s, mccloss - 0.2523, iou_score - 0.637, accuracy - 0.9926, precision - 0.7708, recall - 0.8204, fscore - 0.7625]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.40it/s, mccloss - 0.778, iou_score - 0.6779, accuracy - 0.9905, precision - 0.8803, recall - 0.7801, fscore - 0.7197]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 42
# train: 100%|██████████| 56/56 [00:07<00:00,  7.47it/s, mccloss - 0.2532, iou_score - 0.6412, accuracy - 0.9925, precision - 0.7778, recall - 0.8116, fscore - 0.7635]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.75it/s, mccloss - 0.7771, iou_score - 0.6786, accuracy - 0.9906, precision - 0.8808, recall - 0.78, fscore - 0.7209]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 43
# train: 100%|██████████| 56/56 [00:07<00:00,  7.64it/s, mccloss - 0.2442, iou_score - 0.6508, accuracy - 0.993, precision - 0.7847, recall - 0.8232, fscore - 0.7723]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.33it/s, mccloss - 0.7772, iou_score - 0.6851, accuracy - 0.9905, precision - 0.8861, recall - 0.7815, fscore - 0.7274]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 44
# train: 100%|██████████| 56/56 [00:07<00:00,  7.80it/s, mccloss - 0.2598, iou_score - 0.6285, accuracy - 0.9925, precision - 0.7743, recall - 0.8088, fscore - 0.7541]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.84it/s, mccloss - 0.7829, iou_score - 0.6877, accuracy - 0.9907, precision - 0.899, recall - 0.7724, fscore - 0.7291]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 45
# train: 100%|██████████| 56/56 [00:07<00:00,  7.91it/s, mccloss - 0.2589, iou_score - 0.6327, accuracy - 0.9924, precision - 0.7719, recall - 0.8118, fscore - 0.7571]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.32it/s, mccloss - 0.7801, iou_score - 0.6833, accuracy - 0.9906, precision - 0.8881, recall - 0.7786, fscore - 0.724]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 46
# train: 100%|██████████| 56/56 [00:07<00:00,  7.87it/s, mccloss - 0.2525, iou_score - 0.6375, accuracy - 0.9924, precision - 0.7707, recall - 0.8182, fscore - 0.7648]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.44it/s, mccloss - 0.7734, iou_score - 0.6818, accuracy - 0.9903, precision - 0.8687, recall - 0.7886, fscore - 0.7244]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 47
# train: 100%|██████████| 56/56 [00:07<00:00,  7.95it/s, mccloss - 0.2596, iou_score - 0.6304, accuracy - 0.9924, precision - 0.7632, recall - 0.8135, fscore - 0.7564]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.37it/s, mccloss - 0.7826, iou_score - 0.6888, accuracy - 0.9906, precision - 0.8965, recall - 0.776, fscore - 0.7291]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 48
# train: 100%|██████████| 56/56 [00:07<00:00,  7.94it/s, mccloss - 0.2518, iou_score - 0.6415, accuracy - 0.9926, precision - 0.7658, recall - 0.8281, fscore - 0.7634]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.62it/s, mccloss - 0.7783, iou_score - 0.6785, accuracy - 0.9904, precision - 0.8694, recall - 0.7842, fscore - 0.7198]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 49
# train: 100%|██████████| 56/56 [00:07<00:00,  7.75it/s, mccloss - 0.2588, iou_score - 0.6307, accuracy - 0.9921, precision - 0.7589, recall - 0.8158, fscore - 0.7559]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.43it/s, mccloss - 0.7779, iou_score - 0.6782, accuracy - 0.9905, precision - 0.8788, recall - 0.7819, fscore - 0.7198]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 50
# train: 100%|██████████| 56/56 [00:06<00:00,  8.17it/s, mccloss - 0.265, iou_score - 0.6241, accuracy - 0.9922, precision - 0.7624, recall - 0.805, fscore - 0.7508]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.93it/s, mccloss - 0.7778, iou_score - 0.6933, accuracy - 0.9907, precision - 0.8927, recall - 0.7832, fscore - 0.7349]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 51
# train: 100%|██████████| 56/56 [00:07<00:00,  7.86it/s, mccloss - 0.254, iou_score - 0.6598, accuracy - 0.9927, precision - 0.7942, recall - 0.8094, fscore - 0.7837]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.42it/s, mccloss - 0.7836, iou_score - 0.6883, accuracy - 0.9904, precision - 0.8936, recall - 0.7796, fscore - 0.727]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 52
# train: 100%|██████████| 56/56 [00:07<00:00,  7.91it/s, mccloss - 0.25, iou_score - 0.6433, accuracy - 0.9927, precision - 0.7709, recall - 0.8235, fscore - 0.767]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.34it/s, mccloss - 0.7779, iou_score - 0.6775, accuracy - 0.9905, precision - 0.8731, recall - 0.7797, fscore - 0.7198]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 53
# train: 100%|██████████| 56/56 [00:07<00:00,  7.57it/s, mccloss - 0.2628, iou_score - 0.628, accuracy - 0.9923, precision - 0.7637, recall - 0.8037, fscore - 0.7545]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.31it/s, mccloss - 0.7794, iou_score - 0.6904, accuracy - 0.9906, precision - 0.8943, recall - 0.7789, fscore - 0.7317]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 54
# train: 100%|██████████| 56/56 [00:07<00:00,  7.50it/s, mccloss - 0.2607, iou_score - 0.6325, accuracy - 0.9926, precision - 0.7807, recall - 0.8035, fscore - 0.756]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.83it/s, mccloss - 0.7802, iou_score - 0.6912, accuracy - 0.9906, precision - 0.8931, recall - 0.7807, fscore - 0.7322]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 55
# train: 100%|██████████| 56/56 [00:07<00:00,  7.27it/s, mccloss - 0.2538, iou_score - 0.6381, accuracy - 0.9925, precision - 0.7801, recall - 0.8117, fscore - 0.7627]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.28it/s, mccloss - 0.7757, iou_score - 0.6798, accuracy - 0.9905, precision - 0.8783, recall - 0.7841, fscore - 0.7222]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 56
# train: 100%|██████████| 56/56 [00:07<00:00,  7.78it/s, mccloss - 0.2728, iou_score - 0.6178, accuracy - 0.9921, precision - 0.7702, recall - 0.7916, fscore - 0.7424]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.98it/s, mccloss - 0.7805, iou_score - 0.683, accuracy - 0.9906, precision - 0.889, recall - 0.7771, fscore - 0.7244]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 57
# train: 100%|██████████| 56/56 [00:06<00:00,  8.08it/s, mccloss - 0.2451, iou_score - 0.6484, accuracy - 0.9928, precision - 0.7714, recall - 0.8302, fscore - 0.7701]
# valid: 100%|██████████| 144/144 [00:04<00:00, 28.87it/s, mccloss - 0.7759, iou_score - 0.6862, accuracy - 0.9906, precision - 0.885, recall - 0.7838, fscore - 0.7282]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 58
# train: 100%|██████████| 56/56 [00:07<00:00,  7.83it/s, mccloss - 0.2588, iou_score - 0.6311, accuracy - 0.9923, precision - 0.7596, recall - 0.8179, fscore - 0.7574]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.35it/s, mccloss - 0.7776, iou_score - 0.6785, accuracy - 0.9906, precision - 0.8809, recall - 0.7802, fscore - 0.7206]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 59
# train: 100%|██████████| 56/56 [00:07<00:00,  7.37it/s, mccloss - 0.2503, iou_score - 0.6416, accuracy - 0.9926, precision - 0.7665, recall - 0.8222, fscore - 0.766]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.85it/s, mccloss - 0.7747, iou_score - 0.6808, accuracy - 0.9906, precision - 0.8785, recall - 0.7852, fscore - 0.7237]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 60
# train: 100%|██████████| 56/56 [00:07<00:00,  7.61it/s, mccloss - 0.2478, iou_score - 0.6459, accuracy - 0.9926, precision - 0.7752, recall - 0.8212, fscore - 0.769]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.12it/s, mccloss - 0.7813, iou_score - 0.6827, accuracy - 0.9905, precision - 0.8874, recall - 0.7792, fscore - 0.7232]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
#
# ----------------------------------------------------------
# ['tpi']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:06<00:00,  8.61it/s, mccloss - 0.8659, iou_score - 0.09011, accuracy - 0.6913, precision - 0.09073, recall - 0.9655, fscore - 0.156]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.31it/s, mccloss - 0.9254, iou_score - 0.3936, accuracy - 0.9554, precision - 0.5408, recall - 0.8219, fscore - 0.4333]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:06<00:00,  8.38it/s, mccloss - 0.783, iou_score - 0.1778, accuracy - 0.9032, precision - 0.1808, recall - 0.9432, fscore - 0.2865]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.10it/s, mccloss - 0.8609, iou_score - 0.5228, accuracy - 0.965, precision - 0.5715, recall - 0.9322, fscore - 0.5837]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:06<00:00,  8.22it/s, mccloss - 0.7194, iou_score - 0.242, accuracy - 0.9357, precision - 0.2498, recall - 0.9341, fscore - 0.3671]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.95it/s, mccloss - 0.84, iou_score - 0.603, accuracy - 0.977, precision - 0.6878, recall - 0.9129, fscore - 0.66]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:06<00:00,  8.39it/s, mccloss - 0.6559, iou_score - 0.3105, accuracy - 0.9571, precision - 0.3279, recall - 0.8911, fscore - 0.4451]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.08it/s, mccloss - 0.8152, iou_score - 0.706, accuracy - 0.989, precision - 0.8333, recall - 0.8592, fscore - 0.7523]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:06<00:00,  8.30it/s, mccloss - 0.6106, iou_score - 0.3259, accuracy - 0.9628, precision - 0.3538, recall - 0.8688, fscore - 0.4601]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.74it/s, mccloss - 0.8013, iou_score - 0.7219, accuracy - 0.9888, precision - 0.8548, recall - 0.8572, fscore - 0.7707]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:06<00:00,  8.36it/s, mccloss - 0.5402, iou_score - 0.3853, accuracy - 0.9725, precision - 0.4268, recall - 0.878, fscore - 0.529]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.58it/s, mccloss - 0.7984, iou_score - 0.71, accuracy - 0.9909, precision - 0.8987, recall - 0.8003, fscore - 0.7481]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:04<00:00, 11.84it/s, mccloss - 0.5042, iou_score - 0.4164, accuracy - 0.977, precision - 0.4728, recall - 0.8233, fscore - 0.5603]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.15it/s, mccloss - 0.8665, iou_score - 0.5862, accuracy - 0.9866, precision - 0.9443, recall - 0.6371, fscore - 0.6071]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:04<00:00, 11.78it/s, mccloss - 0.4631, iou_score - 0.444, accuracy - 0.9808, precision - 0.5124, recall - 0.8193, fscore - 0.5894]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.68it/s, mccloss - 0.8898, iou_score - 0.5902, accuracy - 0.9869, precision - 0.9563, recall - 0.6282, fscore - 0.6124]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:04<00:00, 11.85it/s, mccloss - 0.4477, iou_score - 0.4483, accuracy - 0.9823, precision - 0.5285, recall - 0.7858, fscore - 0.5895]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.35it/s, mccloss - 0.775, iou_score - 0.6222, accuracy - 0.9915, precision - 0.8207, recall - 0.7734, fscore - 0.6614]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:04<00:00, 12.20it/s, mccloss - 0.4223, iou_score - 0.4731, accuracy - 0.984, precision - 0.5606, recall - 0.788, fscore - 0.6149]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.48it/s, mccloss - 0.7788, iou_score - 0.7153, accuracy - 0.9913, precision - 0.9352, recall - 0.7712, fscore - 0.7504]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:04<00:00, 11.89it/s, mccloss - 0.3789, iou_score - 0.5387, accuracy - 0.9876, precision - 0.6782, recall - 0.7624, fscore - 0.6718]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.36it/s, mccloss - 0.7863, iou_score - 0.7005, accuracy - 0.9914, precision - 0.9316, recall - 0.7605, fscore - 0.7377]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:04<00:00, 11.37it/s, mccloss - 0.3914, iou_score - 0.4959, accuracy - 0.9856, precision - 0.6245, recall - 0.7672, fscore - 0.6319]
# valid: 100%|██████████| 144/144 [00:03<00:00, 44.37it/s, mccloss - 0.7668, iou_score - 0.722, accuracy - 0.9902, precision - 0.8838, recall - 0.832, fscore - 0.765]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:04<00:00, 11.95it/s, mccloss - 0.3257, iou_score - 0.5702, accuracy - 0.9888, precision - 0.7228, recall - 0.7808, fscore - 0.7037]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.71it/s, mccloss - 0.7474, iou_score - 0.722, accuracy - 0.9912, precision - 0.9013, recall - 0.8022, fscore - 0.7674]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:04<00:00, 11.76it/s, mccloss - 0.3349, iou_score - 0.5552, accuracy - 0.9883, precision - 0.6797, recall - 0.7735, fscore - 0.6866]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.82it/s, mccloss - 0.781, iou_score - 0.7102, accuracy - 0.9912, precision - 0.947, recall - 0.7483, fscore - 0.7522]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:04<00:00, 11.86it/s, mccloss - 0.3443, iou_score - 0.5643, accuracy - 0.9892, precision - 0.7531, recall - 0.7295, fscore - 0.6917]
# valid: 100%|██████████| 144/144 [00:03<00:00, 40.99it/s, mccloss - 0.744, iou_score - 0.7572, accuracy - 0.9919, precision - 0.9076, recall - 0.8341, fscore - 0.7981]
# Model saved!
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:05<00:00, 10.34it/s, mccloss - 0.3074, iou_score - 0.6073, accuracy - 0.9897, precision - 0.7288, recall - 0.795, fscore - 0.73]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.62it/s, mccloss - 0.752, iou_score - 0.7603, accuracy - 0.9923, precision - 0.9455, recall - 0.8052, fscore - 0.7979]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:06<00:00,  9.33it/s, mccloss - 0.2999, iou_score - 0.6157, accuracy - 0.9901, precision - 0.7557, recall - 0.7761, fscore - 0.738]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.65it/s, mccloss - 0.7404, iou_score - 0.755, accuracy - 0.9924, precision - 0.9238, recall - 0.8227, fscore - 0.7946]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:06<00:00,  9.13it/s, mccloss - 0.3061, iou_score - 0.6102, accuracy - 0.9903, precision - 0.7632, recall - 0.7662, fscore - 0.7349]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.14it/s, mccloss - 0.7447, iou_score - 0.758, accuracy - 0.9924, precision - 0.9369, recall - 0.8118, fscore - 0.7973]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:06<00:00,  8.19it/s, mccloss - 0.2854, iou_score - 0.632, accuracy - 0.9906, precision - 0.7757, recall - 0.7958, fscore - 0.7587]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.24it/s, mccloss - 0.7451, iou_score - 0.7566, accuracy - 0.9923, precision - 0.9352, recall - 0.8103, fscore - 0.7974]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:06<00:00,  8.28it/s, mccloss - 0.2654, iou_score - 0.6538, accuracy - 0.9914, precision - 0.8029, recall - 0.798, fscore - 0.7759]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.50it/s, mccloss - 0.7335, iou_score - 0.7587, accuracy - 0.9925, precision - 0.9253, recall - 0.8222, fscore - 0.8002]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:06<00:00,  8.01it/s, mccloss - 0.2709, iou_score - 0.6423, accuracy - 0.9909, precision - 0.7867, recall - 0.808, fscore - 0.7672]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.62it/s, mccloss - 0.7334, iou_score - 0.7585, accuracy - 0.9924, precision - 0.9196, recall - 0.8252, fscore - 0.801]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:06<00:00,  8.30it/s, mccloss - 0.2621, iou_score - 0.6316, accuracy - 0.991, precision - 0.7637, recall - 0.8193, fscore - 0.7575]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.67it/s, mccloss - 0.7234, iou_score - 0.7617, accuracy - 0.9925, precision - 0.9055, recall - 0.8348, fscore - 0.8063]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:06<00:00,  8.61it/s, mccloss - 0.2888, iou_score - 0.613, accuracy - 0.991, precision - 0.7509, recall - 0.7814, fscore - 0.7321]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.01it/s, mccloss - 0.7269, iou_score - 0.7478, accuracy - 0.9923, precision - 0.8956, recall - 0.8293, fscore - 0.7941]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:06<00:00,  8.12it/s, mccloss - 0.266, iou_score - 0.653, accuracy - 0.9916, precision - 0.8006, recall - 0.7991, fscore - 0.7724]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.87it/s, mccloss - 0.7351, iou_score - 0.7452, accuracy - 0.9923, precision - 0.9171, recall - 0.8064, fscore - 0.7907]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:07<00:00,  7.66it/s, mccloss - 0.2768, iou_score - 0.6224, accuracy - 0.9913, precision - 0.7493, recall - 0.7948, fscore - 0.7476]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.59it/s, mccloss - 0.7261, iou_score - 0.7556, accuracy - 0.9924, precision - 0.9144, recall - 0.8262, fscore - 0.802]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:07<00:00,  7.60it/s, mccloss - 0.281, iou_score - 0.6203, accuracy - 0.9916, precision - 0.7862, recall - 0.782, fscore - 0.7426]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.76it/s, mccloss - 0.7442, iou_score - 0.7514, accuracy - 0.9921, precision - 0.9329, recall - 0.8049, fscore - 0.7953]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 27
# train: 100%|██████████| 56/56 [00:07<00:00,  7.67it/s, mccloss - 0.2727, iou_score - 0.6502, accuracy - 0.9918, precision - 0.8205, recall - 0.7813, fscore - 0.7697]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.91it/s, mccloss - 0.7349, iou_score - 0.7628, accuracy - 0.9924, precision - 0.929, recall - 0.8194, fscore - 0.8078]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 56/56 [00:06<00:00,  8.09it/s, mccloss - 0.2597, iou_score - 0.6593, accuracy - 0.9915, precision - 0.7905, recall - 0.7986, fscore - 0.7786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.12it/s, mccloss - 0.7266, iou_score - 0.7631, accuracy - 0.9923, precision - 0.9147, recall - 0.8354, fscore - 0.8074]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 29
# train: 100%|██████████| 56/56 [00:07<00:00,  7.92it/s, mccloss - 0.2628, iou_score - 0.6353, accuracy - 0.9915, precision - 0.7624, recall - 0.8056, fscore - 0.7541]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.65it/s, mccloss - 0.7404, iou_score - 0.7574, accuracy - 0.9922, precision - 0.9318, recall - 0.8118, fscore - 0.8016]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 30
# train: 100%|██████████| 56/56 [00:07<00:00,  7.88it/s, mccloss - 0.2736, iou_score - 0.6352, accuracy - 0.9918, precision - 0.8007, recall - 0.7856, fscore - 0.7506]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.46it/s, mccloss - 0.7324, iou_score - 0.7659, accuracy - 0.9923, precision - 0.92, recall - 0.823, fscore - 0.8103]
# Model saved!
# Decrease decoder learning rate by factor of 10
#
# Epoch: 31
# train: 100%|██████████| 56/56 [00:07<00:00,  7.93it/s, mccloss - 0.2435, iou_score - 0.6746, accuracy - 0.9919, precision - 0.8027, recall - 0.8219, fscore - 0.7955]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.84it/s, mccloss - 0.7329, iou_score - 0.7658, accuracy - 0.9923, precision - 0.9168, recall - 0.826, fscore - 0.8099]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 32
# train: 100%|██████████| 56/56 [00:06<00:00,  8.06it/s, mccloss - 0.2616, iou_score - 0.6438, accuracy - 0.992, precision - 0.7971, recall - 0.8005, fscore - 0.7601]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.29it/s, mccloss - 0.7294, iou_score - 0.7684, accuracy - 0.9923, precision - 0.9201, recall - 0.8269, fscore - 0.8128]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 56/56 [00:06<00:00,  8.37it/s, mccloss - 0.26, iou_score - 0.6576, accuracy - 0.9919, precision - 0.7922, recall - 0.7979, fscore - 0.7798]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.86it/s, mccloss - 0.731, iou_score - 0.7671, accuracy - 0.9923, precision - 0.9205, recall - 0.8249, fscore - 0.8117]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 34
# train: 100%|██████████| 56/56 [00:07<00:00,  7.78it/s, mccloss - 0.2495, iou_score - 0.6549, accuracy - 0.9919, precision - 0.7845, recall - 0.8232, fscore - 0.7738]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.59it/s, mccloss - 0.7238, iou_score - 0.7726, accuracy - 0.9922, precision - 0.9123, recall - 0.841, fscore - 0.8169]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 56/56 [00:07<00:00,  7.81it/s, mccloss - 0.2523, iou_score - 0.665, accuracy - 0.9917, precision - 0.8055, recall - 0.8131, fscore - 0.7828]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.93it/s, mccloss - 0.7273, iou_score - 0.7703, accuracy - 0.9923, precision - 0.9166, recall - 0.8329, fscore - 0.8144]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 36
# train: 100%|██████████| 56/56 [00:07<00:00,  7.73it/s, mccloss - 0.2448, iou_score - 0.6702, accuracy - 0.9915, precision - 0.7987, recall - 0.8244, fscore - 0.7914]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.67it/s, mccloss - 0.7284, iou_score - 0.7699, accuracy - 0.9923, precision - 0.917, recall - 0.8324, fscore - 0.8141]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 37
# train: 100%|██████████| 56/56 [00:06<00:00,  8.01it/s, mccloss - 0.2665, iou_score - 0.6539, accuracy - 0.9918, precision - 0.8274, recall - 0.7806, fscore - 0.7706]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.55it/s, mccloss - 0.729, iou_score - 0.7687, accuracy - 0.9922, precision - 0.9165, recall - 0.8318, fscore - 0.8134]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 38
# train: 100%|██████████| 56/56 [00:07<00:00,  7.61it/s, mccloss - 0.2555, iou_score - 0.6562, accuracy - 0.9915, precision - 0.7901, recall - 0.8056, fscore - 0.7785]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.81it/s, mccloss - 0.7318, iou_score - 0.7658, accuracy - 0.9923, precision - 0.9206, recall - 0.8233, fscore - 0.8106]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 39
# train: 100%|██████████| 56/56 [00:06<00:00,  8.29it/s, mccloss - 0.2837, iou_score - 0.6416, accuracy - 0.9918, precision - 0.8228, recall - 0.7745, fscore - 0.7556]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.85it/s, mccloss - 0.7266, iou_score - 0.7711, accuracy - 0.9923, precision - 0.9186, recall - 0.8327, fscore - 0.8151]
# No improvement in 5 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training
#
#
# ----------------------------------------------------------
# ['shade']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:06<00:00,  9.19it/s, mccloss - 0.9229, iou_score - 0.04321, accuracy - 0.4106, precision - 0.04349, recall - 0.9152, fscore - 0.08114]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.75it/s, mccloss - 0.9629, iou_score - 0.02524, accuracy - 0.3636, precision - 0.02532, recall - 0.9097, fscore - 0.04547]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:06<00:00,  8.69it/s, mccloss - 0.8451, iou_score - 0.08794, accuracy - 0.7442, precision - 0.08888, recall - 0.8563, fscore - 0.1547]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.01it/s, mccloss - 0.9472, iou_score - 0.4853, accuracy - 0.9625, precision - 0.7123, recall - 0.7172, fscore - 0.5135]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:06<00:00,  8.31it/s, mccloss - 0.7921, iou_score - 0.1346, accuracy - 0.8467, precision - 0.1379, recall - 0.86, fscore - 0.2241]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.05it/s, mccloss - 0.9204, iou_score - 0.2406, accuracy - 0.8788, precision - 0.3556, recall - 0.7917, fscore - 0.275]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:06<00:00,  8.72it/s, mccloss - 0.7644, iou_score - 0.1545, accuracy - 0.8742, precision - 0.1609, recall - 0.8156, fscore - 0.2514]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.77it/s, mccloss - 0.9755, iou_score - 0.4375, accuracy - 0.9773, precision - 0.7451, recall - 0.6118, fscore - 0.452]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:06<00:00,  9.32it/s, mccloss - 0.7283, iou_score - 0.179, accuracy - 0.898, precision - 0.1905, recall - 0.8197, fscore - 0.2863]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.77it/s, mccloss - 0.9005, iou_score - 0.2734, accuracy - 0.9523, precision - 0.3265, recall - 0.7777, fscore - 0.31]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:06<00:00,  9.11it/s, mccloss - 0.6957, iou_score - 0.2122, accuracy - 0.9207, precision - 0.2288, recall - 0.7825, fscore - 0.326]
# valid: 100%|██████████| 144/144 [00:03<00:00, 41.25it/s, mccloss - 0.9036, iou_score - 0.3672, accuracy - 0.9461, precision - 0.4992, recall - 0.7616, fscore - 0.4035]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:04<00:00, 12.31it/s, mccloss - 0.677, iou_score - 0.2325, accuracy - 0.9345, precision - 0.257, recall - 0.7064, fscore - 0.3488]
# valid: 100%|██████████| 144/144 [00:03<00:00, 44.72it/s, mccloss - 0.9122, iou_score - 0.3896, accuracy - 0.9624, precision - 0.617, recall - 0.6975, fscore - 0.4173]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:04<00:00, 12.52it/s, mccloss - 0.6734, iou_score - 0.2322, accuracy - 0.9377, precision - 0.2656, recall - 0.6714, fscore - 0.3465]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.17it/s, mccloss - 0.9133, iou_score - 0.4602, accuracy - 0.9803, precision - 0.71, recall - 0.6799, fscore - 0.4836]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:04<00:00, 13.04it/s, mccloss - 0.6341, iou_score - 0.26, accuracy - 0.9485, precision - 0.3042, recall - 0.6898, fscore - 0.3812]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.29it/s, mccloss - 0.8757, iou_score - 0.5198, accuracy - 0.9826, precision - 0.7506, recall - 0.7232, fscore - 0.5504]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:04<00:00, 12.94it/s, mccloss - 0.6216, iou_score - 0.2704, accuracy - 0.9528, precision - 0.3254, recall - 0.6509, fscore - 0.3938]
# valid: 100%|██████████| 144/144 [00:03<00:00, 41.27it/s, mccloss - 0.9196, iou_score - 0.5851, accuracy - 0.9854, precision - 0.9029, recall - 0.6509, fscore - 0.6048]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:04<00:00, 12.61it/s, mccloss - 0.7125, iou_score - 0.2017, accuracy - 0.9474, precision - 0.2509, recall - 0.4915, fscore - 0.3059]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.99it/s, mccloss - 0.8982, iou_score - 0.4158, accuracy - 0.9735, precision - 0.6512, recall - 0.6721, fscore - 0.4405]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:04<00:00, 13.42it/s, mccloss - 0.6251, iou_score - 0.2614, accuracy - 0.9542, precision - 0.3226, recall - 0.6235, fscore - 0.3808]
# valid: 100%|██████████| 144/144 [00:03<00:00, 47.33it/s, mccloss - 0.8749, iou_score - 0.2971, accuracy - 0.958, precision - 0.4602, recall - 0.7344, fscore - 0.3286]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:04<00:00, 12.54it/s, mccloss - 0.6195, iou_score - 0.2622, accuracy - 0.9565, precision - 0.3286, recall - 0.6158, fscore - 0.3873]
# valid: 100%|██████████| 144/144 [00:03<00:00, 42.12it/s, mccloss - 0.9767, iou_score - 0.5666, accuracy - 0.9849, precision - 0.9705, recall - 0.581, fscore - 0.5741]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:04<00:00, 12.87it/s, mccloss - 0.6027, iou_score - 0.2768, accuracy - 0.9604, precision - 0.3622, recall - 0.5897, fscore - 0.4033]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.32it/s, mccloss - 0.8458, iou_score - 0.4305, accuracy - 0.9759, precision - 0.558, recall - 0.7574, fscore - 0.4646]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:04<00:00, 12.04it/s, mccloss - 0.58, iou_score - 0.3008, accuracy - 0.9645, precision - 0.3883, recall - 0.5973, fscore - 0.4264]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.65it/s, mccloss - 0.8487, iou_score - 0.4334, accuracy - 0.9736, precision - 0.5965, recall - 0.7791, fscore - 0.4705]
# No improvement in 5 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:04<00:00, 12.22it/s, mccloss - 0.5732, iou_score - 0.2956, accuracy - 0.9647, precision - 0.3953, recall - 0.6183, fscore - 0.4289]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.55it/s, mccloss - 0.8406, iou_score - 0.5497, accuracy - 0.9825, precision - 0.7281, recall - 0.7663, fscore - 0.5849]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:05<00:00, 10.12it/s, mccloss - 0.5466, iou_score - 0.3246, accuracy - 0.9679, precision - 0.4128, recall - 0.6462, fscore - 0.4562]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.79it/s, mccloss - 0.8388, iou_score - 0.573, accuracy - 0.983, precision - 0.7434, recall - 0.7632, fscore - 0.6076]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:05<00:00, 10.15it/s, mccloss - 0.5453, iou_score - 0.3308, accuracy - 0.9691, precision - 0.4257, recall - 0.6228, fscore - 0.4622]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.96it/s, mccloss - 0.8383, iou_score - 0.5746, accuracy - 0.9838, precision - 0.7391, recall - 0.7586, fscore - 0.6086]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:06<00:00,  8.38it/s, mccloss - 0.5486, iou_score - 0.3313, accuracy - 0.9689, precision - 0.4249, recall - 0.6243, fscore - 0.4586]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.99it/s, mccloss - 0.839, iou_score - 0.5649, accuracy - 0.9823, precision - 0.7111, recall - 0.7646, fscore - 0.6003]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:05<00:00,  9.69it/s, mccloss - 0.5529, iou_score - 0.3242, accuracy - 0.97, precision - 0.4254, recall - 0.6114, fscore - 0.4544]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.38it/s, mccloss - 0.837, iou_score - 0.5893, accuracy - 0.984, precision - 0.7465, recall - 0.7601, fscore - 0.6236]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:06<00:00,  9.00it/s, mccloss - 0.549, iou_score - 0.3327, accuracy - 0.9704, precision - 0.4325, recall - 0.6104, fscore - 0.4576]
# valid: 100%|██████████| 144/144 [00:04<00:00, 28.98it/s, mccloss - 0.8483, iou_score - 0.5975, accuracy - 0.9856, precision - 0.7963, recall - 0.7376, fscore - 0.6267]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:06<00:00,  8.94it/s, mccloss - 0.5259, iou_score - 0.3431, accuracy - 0.9711, precision - 0.44, recall - 0.6456, fscore - 0.4801]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.92it/s, mccloss - 0.8398, iou_score - 0.561, accuracy - 0.984, precision - 0.7086, recall - 0.7555, fscore - 0.5934]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:06<00:00,  9.00it/s, mccloss - 0.5099, iou_score - 0.3532, accuracy - 0.972, precision - 0.4608, recall - 0.6748, fscore - 0.491]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.14it/s, mccloss - 0.8433, iou_score - 0.5982, accuracy - 0.9843, precision - 0.7619, recall - 0.7502, fscore - 0.6304]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:05<00:00,  9.58it/s, mccloss - 0.5228, iou_score - 0.3473, accuracy - 0.9703, precision - 0.4431, recall - 0.6441, fscore - 0.4823]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.46it/s, mccloss - 0.8444, iou_score - 0.5898, accuracy - 0.9845, precision - 0.7694, recall - 0.7504, fscore - 0.6222]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:06<00:00,  9.14it/s, mccloss - 0.5247, iou_score - 0.3374, accuracy - 0.9708, precision - 0.4362, recall - 0.6567, fscore - 0.4757]
# ...
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:07<00:00,  7.21it/s, mccloss - nan, iou_score - 0.04331, accuracy - 0.5742, precision - 0.0438, recall - 0.8726, fscore - 0.08141]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.12it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:07<00:00,  7.51it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9777, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.76it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:05<00:00,  9.81it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 39.74it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:05<00:00, 10.17it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9783, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.50it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:06<00:00,  8.60it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.56it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:05<00:00, 10.10it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9777, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.18it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:05<00:00, 10.24it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.03it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:05<00:00,  9.84it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9783, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.80it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:05<00:00,  9.79it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.22it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:05<00:00,  9.89it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.12it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:06<00:00,  8.22it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.84it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:07<00:00,  7.95it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.50it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:06<00:00,  8.51it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.40it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:07<00:00,  7.47it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.49it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:07<00:00,  7.36it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9777, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.77it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 14 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:08<00:00,  6.89it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9782, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.74it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:07<00:00,  7.33it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.34it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:07<00:00,  7.24it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.08it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:07<00:00,  7.17it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9777, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.77it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:07<00:00,  7.04it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9785, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.37it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 5 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:08<00:00,  6.80it/s, mccloss - nan, iou_score - 0.08617, accuracy - 0.8216, precision - 0.08878, recall - 0.7862, fscore - 0.1525]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.65it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:08<00:00,  6.80it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 26.55it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:08<00:00,  6.57it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.28it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:08<00:00,  6.68it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9776, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.38it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:08<00:00,  6.77it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.54it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:08<00:00,  6.71it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.29it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:08<00:00,  6.67it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9778, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.56it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:08<00:00,  6.78it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.21it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:08<00:00,  6.53it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9776, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.00it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:07<00:00,  7.73it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9782, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.56it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:06<00:00,  8.91it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9784, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.53it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:06<00:00,  9.09it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.75it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:06<00:00,  8.13it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9774, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.69it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:06<00:00,  8.15it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9779, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.12it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:07<00:00,  8.00it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9782, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.97it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 14 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:06<00:00,  8.90it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9783, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.62it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:06<00:00,  8.55it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9781, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.40it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:07<00:00,  7.57it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.978, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.77it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:07<00:00,  7.45it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9782, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.34it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:08<00:00,  6.84it/s, mccloss - nan, iou_score - 0.01786, accuracy - 0.9777, precision - 1.0, recall - 0.01786, fscore - 0.01786]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.43it/s, mccloss - nan, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 5 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training

# %%
print('All processing complete!')
# Out:
# All processing complete!
