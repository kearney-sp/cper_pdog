# %%
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
#os.environ['LD_LIBRARY_PATH']= '$LD_LIBRARY_PATH:/usr/local/cuda/extras/CUPTI/lib64'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prep lists of input files

# %%
from glob import glob
import re
import pandas as pd
from random import sample, seed

# %%
encoder_list = ['resnet34']
avail_suffix = ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']

# %%
# set working directory
os.chdir('/project/cper_neon_aop/cper_pdog_uas')

# set directories for training data and labels
DATA_FOLDER = './cnn_train_images/{}_{}.tif'
LABEL_FOLDER = './cnn_train_labels/{}_labels.tif'

# %%
# read in csvs with training information
df_tiles = pd.read_csv('train_tiles/train_bboxes_all_assigned.csv')
df_polys = pd.read_csv('train_polys/train_polys_all.csv')

# %%
# get all ids to be used
label_files = glob(LABEL_FOLDER.replace('{}', '*'))
all_ids = [re.sub('_labels.tif', '', os.path.basename(f)) for f in label_files]
all_tiles = list(set(['_'.join(y.split('_')[2:]) for y in all_ids]))

# %%
# separate training and test data and get paths to files
all_files = glob(DATA_FOLDER.replace('{}', '*'))
all_train_tiles = [x for x in df_tiles.apply(lambda x: '_'.join([x.Pasture, x.Tile]) if x.Train == 1 else '', axis=1) if x != '' and x in all_tiles]
test_tiles = list(set(all_tiles) - set(all_train_tiles))

all_train_ids = [x for x in all_ids if '_'.join(x.split('_')[-3:]) in all_train_tiles]
test_ids = list(set(all_ids) - set(all_train_ids))

seed(321)
valid_ids = sample(all_train_ids, int(np.ceil(len(all_train_ids)*0.3)))
train_ids = list(set(all_train_ids) - set(valid_ids))

train_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in train_ids]
valid_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in valid_ids]
test_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in test_ids]

# %%
tile_ids = df_tiles[(df_tiles['trainer'] != 'Nick') &
                    (df_tiles['Digitize'] == 1)].apply(lambda x: '_'.join([x.Pasture, x.Tile]), axis=1)
#all_tiles#
[x for x in all_tiles if x not in tile_ids.to_list()]
# Out:
# []

# %%
[x for x in tile_ids.to_list() if x not in all_tiles]
# Out:
# []

# %% [markdown]
# ### Dataloader
# Writing helper class for data extraction, tranformation and preprocessing

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset
from skimage import io

# %%
class Dataset(BaseDataset):
    """Read images, apply augmentation and preprocessing transformations.
    
    Args:
        ids (list): list of unique ids for all images
        images_path (str): path to data images
        masks_path (str): path to label masks
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    
    CLASSES = ['other', 'burrow']
    
    def __init__(
            self, 
            ids,
            suffix_list,
            images_path,
            masks_path, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
            suffix_dict = {
        'rgb': {'channels': 3,
                'dtype': 'uint8'},
        'tpi': {'channels': 1,
                'dtype': 'float32'},
        'dsm': {'channels': 1,
                'dtype': 'float32'},
        'shade': {'channels': 1,
                  'dtype': 'float32'},
        'ndvi': {'channels': 1,
                  'dtype': 'float32'}
    }
    ):
        # get IDs as attribute
        self.ids = ids
        
        # get suffix info
        self.suffix_dict = suffix_dict
        
        # get list of suffixes as attribute
        self.suffix_list = suffix_list
        
        # List of files
        self.images_fps = []
        self.masks_fps = [masks_path.format(id) for id in ids]
        for id in ids:
            self.images_fps.append({s: images_path.format(id, s) for s in suffix_list})
            
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image_list = []
        self.image_dict = {}
        for s in self.suffix_list:
            image_s = np.asarray(io.imread(self.images_fps[i][s]), dtype=self.suffix_dict[s]['dtype'])
            if len(image_s.shape) == 2:
                image_s = np.expand_dims(image_s, axis=-1)
            image_s[np.isnan(image_s)] = 0
            image_list.append(image_s)
            self.image_dict[s] = image_s
        if len(image_list) == 1:
            image = image_list[0]
        else:
            image = np.concatenate(image_list, axis=-1)
        mask = np.asarray(io.imread(self.masks_fps[i]), dtype='float32')
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1)#.astype('float32')
        #print('fetched: ', self.ids[i])
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        else:
            image = torch.from_numpy(image.transpose(2, 0, 1).astype('float32'))
            mask = torch.from_numpy(mask.transpose(2, 0, 1).astype('float32'))
        return image, mask
        
    def __len__(self):
        return len(self.ids)

# %% [markdown]
# ### Augmentations

# %%
import albumentations as albu
import random

# %%
def get_training_augmentation():
    win_size = 32 * random.randint(7, 10)
    train_transform = [

        albu.HorizontalFlip(p=0.5),
        albu.VerticalFlip(p=0.5),

        #albu.ShiftScaleRotate(scale_limit=0.0, rotate_limit=45, shift_limit=0.1, p=1, border_mode=0),

        #albu.PadIfNeeded(min_height=win_size, min_width=win_size, always_apply=True, border_mode=4),
        albu.RandomCrop(height=win_size, width=win_size, always_apply=True),

        #albu.GaussNoise(p=0.2, var_limit=1.0),
        #albu.Perspective(p=0.5),

        #albu.OneOf(
        #    [
        #        #albu.CLAHE(p=1), # required int8 images
        #        albu.RandomBrightnessContrast(p=1),
        #        #albu.RandomGamma(p=1),
        #        #albu.HueSaturationValue(p=1),
        #    ],
        #    p=0.9,
        #),

        albu.OneOf(
            [
                albu.Sharpen(p=1),
                albu.Blur(blur_limit=(3, 7), p=1),
                albu.MotionBlur(blur_limit=(3, 7), p=1),
            ],
            p=0.25,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.PadIfNeeded(384, 480)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %% [markdown]
# ### Create and train model

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils
import torch.nn as nn
import gc

# %%
ENCODER = 'resnet34'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['burrow']
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #'cuda'# 'cpu'# 
USE_PARALLEL = True

# %%
import itertools
#list(itertools.combinations(avail_suffix, len(avail_suffix)))
suffix_combinations = list()
for n in range(1, len(avail_suffix) + 1):
    suffix_combinations += list(itertools.combinations(avail_suffix, n))

# %%
outDIR = './cnn_results_deeplabplus/'
if not os.path.exists(outDIR):
    os.mkdir(outDIR)

# %%
for suffix_sub in suffix_combinations:
    suffix_list = list(suffix_sub)
    print('\n\n----------------------------------------------------------')
    print(suffix_list)
    if os.path.exists(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt'):
        print('skipping - already trained.')
        continue
    else:
        train_dataset = Dataset(
            train_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            augmentation=get_training_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)

        valid_dataset = Dataset(
            valid_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            #augmentation=get_validation_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)


        train_loader = DataLoader(train_dataset, batch_size=6, shuffle=False,
                                  drop_last=True, num_workers=6, pin_memory=False)
        valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=6, pin_memory=False)

        # create segmentation model with pretrained encoder
        model = smp.DeepLabV3Plus(
            encoder_name=ENCODER, 
            encoder_weights=ENCODER_WEIGHTS, 
            classes=len(CLASSES), 
            activation=ACTIVATION,
            in_channels=train_dataset[0][0].shape[0],
        )
        
        if USE_PARALLEL:
            model = nn.DataParallel(model)

        preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

        # Dice/F1 score - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
        # IoU/Jaccard score - https://en.wikipedia.org/wiki/Jaccard_index

        loss = smp.losses.MCCLoss()
        loss.__name__ = 'mccloss'
        metrics = [
            utils.metrics.IoU(threshold=0.5),
            utils.metrics.Accuracy(threshold=0.5),
            utils.metrics.Precision(threshold=0.5),
            utils.metrics.Recall(threshold=0.5),
            utils.metrics.Fscore(threshold=0.5)
        ]

        optimizer = torch.optim.Adam([ 
            dict(params=model.parameters(), lr=0.0001),
        ])

        # create epoch runners 
        # it is a simple loop of iterating over dataloader`s samples
        train_epoch = utils.train.TrainEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            optimizer=optimizer,
            device=DEVICE,
            verbose=True,
        )

        valid_epoch = utils.train.ValidEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            device=DEVICE,
            verbose=True,
        )

        # train model for up to 60 epochs

        max_score = 0
        max_score_train = 0
        no_improve = 0

        for i in range(1, 61):

            print('\nEpoch: {}'.format(i))
            train_logs = train_epoch.run(train_loader)
            valid_logs = valid_epoch.run(valid_loader)

            # do something (save model, change lr, etc.)
            if max_score < valid_logs['fscore']:
                max_score = valid_logs['fscore']
                max_score_train = train_logs['fscore']
                torch.save(model, outDIR + 'best_model_' + '_'.join(suffix_list) + '.pth')
                valid_logs['best_epoch'] = i
                best_valid_logs = valid_logs.copy()
                print('Model saved!')
                no_improve = 0
            else:
                no_improve += 1
                print('No improvement in ' + str(no_improve) + ' epochs. Model not saved.')

            if i > 15:
                if no_improve >= 5:
                    if (train_logs['fscore'] - max_score_train) < 0.05:
                        print('More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
                    elif (train_logs['fscore'] - max_score_train) < 0.10 and no_improve == 15:
                        print('15 epochs without validation improvement while learning rate <= 1e-5...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
            if i == 60:
                with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        
            if i%15 == 0:
                no_improve = 0
                optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr'] * 0.1
                print('Decrease decoder learning rate by factor of 10')

        del model, train_epoch, valid_epoch
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ----------------------------------------------------------
# ['rgb']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:29<00:00,  1.88it/s, mccloss - 0.8602, iou_score - 0.1083, accuracy - 0.7339, precision - 0.1101, recall - 0.881, fscore - 0.1863]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.42it/s, mccloss - 0.9261, iou_score - 0.0817, accuracy - 0.8106, precision - 0.08259, recall - 0.8985, fscore - 0.1208]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:05<00:00, 10.67it/s, mccloss - 0.7681, iou_score - 0.1637, accuracy - 0.8458, precision - 0.1673, recall - 0.9048, fscore - 0.2651]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.66it/s, mccloss - 0.9092, iou_score - 0.322, accuracy - 0.9333, precision - 0.4214, recall - 0.8316, fscore - 0.3615]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:04<00:00, 11.42it/s, mccloss - 0.7085, iou_score - 0.2267, accuracy - 0.8994, precision - 0.235, recall - 0.8992, fscore - 0.3468]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.27it/s, mccloss - 0.9028, iou_score - 0.6459, accuracy - 0.9826, precision - 0.8403, recall - 0.7696, fscore - 0.684]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:05<00:00, 10.64it/s, mccloss - 0.6545, iou_score - 0.2781, accuracy - 0.9282, precision - 0.3003, recall - 0.8755, fscore - 0.4113]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.06it/s, mccloss - 0.9529, iou_score - 0.6048, accuracy - 0.9859, precision - 0.9577, recall - 0.6407, fscore - 0.6204]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:05<00:00, 11.08it/s, mccloss - 0.6385, iou_score - 0.2868, accuracy - 0.9384, precision - 0.323, recall - 0.7995, fscore - 0.4177]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.28it/s, mccloss - 0.931, iou_score - 0.08386, accuracy - 0.8185, precision - 0.08478, recall - 0.848, fscore - 0.1159]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:05<00:00, 10.94it/s, mccloss - 0.6137, iou_score - 0.3024, accuracy - 0.9451, precision - 0.3489, recall - 0.7687, fscore - 0.4302]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.67it/s, mccloss - 0.8388, iou_score - 0.3804, accuracy - 0.9409, precision - 0.4445, recall - 0.8924, fscore - 0.4314]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:05<00:00, 10.45it/s, mccloss - 0.5559, iou_score - 0.3371, accuracy - 0.953, precision - 0.3922, recall - 0.7896, fscore - 0.4794]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.69it/s, mccloss - 0.823, iou_score - 0.4781, accuracy - 0.9724, precision - 0.5579, recall - 0.8387, fscore - 0.5249]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:05<00:00, 11.01it/s, mccloss - 0.5585, iou_score - 0.3267, accuracy - 0.9535, precision - 0.3848, recall - 0.7977, fscore - 0.4619]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.73it/s, mccloss - 0.8249, iou_score - 0.3686, accuracy - 0.9602, precision - 0.3936, recall - 0.8593, fscore - 0.4197]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:05<00:00, 10.81it/s, mccloss - 0.5472, iou_score - 0.3403, accuracy - 0.9589, precision - 0.4163, recall - 0.7249, fscore - 0.4773]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.10it/s, mccloss - 0.8219, iou_score - 0.2132, accuracy - 0.9344, precision - 0.2191, recall - 0.9054, fscore - 0.2679]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:05<00:00, 11.01it/s, mccloss - 0.5156, iou_score - 0.3579, accuracy - 0.9592, precision - 0.4247, recall - 0.7613, fscore - 0.4987]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.64it/s, mccloss - 0.7919, iou_score - 0.5365, accuracy - 0.9767, precision - 0.6094, recall - 0.8637, fscore - 0.591]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:04<00:00, 11.28it/s, mccloss - 0.5049, iou_score - 0.3713, accuracy - 0.9643, precision - 0.4585, recall - 0.7169, fscore - 0.5114]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.45it/s, mccloss - 0.8094, iou_score - 0.6552, accuracy - 0.9865, precision - 0.8156, recall - 0.7933, fscore - 0.6953]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:05<00:00, 10.65it/s, mccloss - 0.4521, iou_score - 0.4162, accuracy - 0.9702, precision - 0.5089, recall - 0.7615, fscore - 0.562]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.74it/s, mccloss - 0.7838, iou_score - 0.5721, accuracy - 0.9789, precision - 0.6638, recall - 0.8756, fscore - 0.6247]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:05<00:00, 10.90it/s, mccloss - 0.4782, iou_score - 0.4052, accuracy - 0.972, precision - 0.5053, recall - 0.7247, fscore - 0.5432]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.69it/s, mccloss - 0.8089, iou_score - 0.6541, accuracy - 0.9795, precision - 0.7721, recall - 0.8455, fscore - 0.7016]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:05<00:00, 10.80it/s, mccloss - 0.4575, iou_score - 0.4206, accuracy - 0.973, precision - 0.543, recall - 0.7197, fscore - 0.5601]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.49it/s, mccloss - 0.8055, iou_score - 0.3458, accuracy - 0.9445, precision - 0.3796, recall - 0.9062, fscore - 0.399]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:05<00:00, 10.52it/s, mccloss - 0.4598, iou_score - 0.4022, accuracy - 0.9696, precision - 0.5016, recall - 0.7451, fscore - 0.5459]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.77it/s, mccloss - 0.8287, iou_score - 0.5949, accuracy - 0.9746, precision - 0.7524, recall - 0.7957, fscore - 0.6344]
# No improvement in 2 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:05<00:00, 11.17it/s, mccloss - 0.4145, iou_score - 0.4667, accuracy - 0.9773, precision - 0.6334, recall - 0.7008, fscore - 0.609]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.85it/s, mccloss - 0.7791, iou_score - 0.623, accuracy - 0.9836, precision - 0.7441, recall - 0.8405, fscore - 0.6702]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:05<00:00, 10.80it/s, mccloss - 0.4322, iou_score - 0.4594, accuracy - 0.9789, precision - 0.6234, recall - 0.6666, fscore - 0.589]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.09it/s, mccloss - 0.7746, iou_score - 0.646, accuracy - 0.9864, precision - 0.777, recall - 0.8276, fscore - 0.6906]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:05<00:00, 10.73it/s, mccloss - 0.4081, iou_score - 0.5057, accuracy - 0.9804, precision - 0.7229, recall - 0.6789, fscore - 0.6371]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.54it/s, mccloss - 0.7728, iou_score - 0.648, accuracy - 0.9864, precision - 0.7768, recall - 0.8287, fscore - 0.6936]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:05<00:00, 10.90it/s, mccloss - 0.4012, iou_score - 0.4996, accuracy - 0.9799, precision - 0.6614, recall - 0.6999, fscore - 0.6388]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.09it/s, mccloss - 0.7681, iou_score - 0.6666, accuracy - 0.9863, precision - 0.7874, recall - 0.8359, fscore - 0.713]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:05<00:00, 11.01it/s, mccloss - 0.3645, iou_score - 0.5236, accuracy - 0.9809, precision - 0.6759, recall - 0.7407, fscore - 0.6627]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.97it/s, mccloss - 0.7743, iou_score - 0.6523, accuracy - 0.9848, precision - 0.7771, recall - 0.8359, fscore - 0.6987]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:05<00:00, 10.80it/s, mccloss - 0.371, iou_score - 0.5536, accuracy - 0.9808, precision - 0.7418, recall - 0.7308, fscore - 0.6894]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.07it/s, mccloss - 0.7651, iou_score - 0.6587, accuracy - 0.9854, precision - 0.775, recall - 0.8455, fscore - 0.7067]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:05<00:00, 11.12it/s, mccloss - 0.3603, iou_score - 0.5566, accuracy - 0.9823, precision - 0.7271, recall - 0.744, fscore - 0.6853]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.37it/s, mccloss - 0.7665, iou_score - 0.6657, accuracy - 0.9866, precision - 0.7878, recall - 0.8364, fscore - 0.7113]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:05<00:00, 10.01it/s, mccloss - 0.3903, iou_score - 0.5188, accuracy - 0.981, precision - 0.7146, recall - 0.7153, fscore - 0.6479]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.03it/s, mccloss - 0.7824, iou_score - 0.6844, accuracy - 0.9891, precision - 0.8536, recall - 0.7842, fscore - 0.7266]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:04<00:00, 11.35it/s, mccloss - 0.3786, iou_score - 0.5652, accuracy - 0.9826, precision - 0.7884, recall - 0.6996, fscore - 0.6999]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.08it/s, mccloss - 0.7676, iou_score - 0.6645, accuracy - 0.9863, precision - 0.7887, recall - 0.8362, fscore - 0.7103]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:04<00:00, 11.30it/s, mccloss - 0.3716, iou_score - 0.5483, accuracy - 0.9805, precision - 0.7254, recall - 0.7526, fscore - 0.6777]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.46it/s, mccloss - 0.7624, iou_score - 0.6617, accuracy - 0.985, precision - 0.7559, recall - 0.8548, fscore - 0.7095]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:05<00:00, 10.75it/s, mccloss - 0.3748, iou_score - 0.5336, accuracy - 0.9811, precision - 0.7154, recall - 0.7399, fscore - 0.662]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.06it/s, mccloss - 0.7625, iou_score - 0.6568, accuracy - 0.9862, precision - 0.7736, recall - 0.844, fscore - 0.7037]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 27
# train: 100%|██████████| 56/56 [00:04<00:00, 11.24it/s, mccloss - 0.3916, iou_score - 0.5193, accuracy - 0.981, precision - 0.6796, recall - 0.7179, fscore - 0.6462]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.82it/s, mccloss - 0.7593, iou_score - 0.6527, accuracy - 0.9867, precision - 0.7733, recall - 0.8394, fscore - 0.6989]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 28
# train: 100%|██████████| 56/56 [00:05<00:00, 10.57it/s, mccloss - 0.3642, iou_score - 0.5854, accuracy - 0.9835, precision - 0.7841, recall - 0.7251, fscore - 0.714]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.79it/s, mccloss - 0.764, iou_score - 0.6477, accuracy - 0.9865, precision - 0.7702, recall - 0.8387, fscore - 0.6945]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 29
# train: 100%|██████████| 56/56 [00:05<00:00, 10.76it/s, mccloss - 0.3795, iou_score - 0.5005, accuracy - 0.9786, precision - 0.6367, recall - 0.756, fscore - 0.6354]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.60it/s, mccloss - 0.7668, iou_score - 0.6275, accuracy - 0.9836, precision - 0.7251, recall - 0.86, fscore - 0.6755]
# No improvement in 6 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:05<00:00, 10.50it/s, mccloss - 0.9068, iou_score - 0.04866, accuracy - 0.624, precision - 0.04923, recall - 0.8474, fscore - 0.09094]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.63it/s, mccloss - 0.9814, iou_score - 0.02206, accuracy - 0.4143, precision - 0.02216, recall - 0.8821, fscore - 0.04038]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:05<00:00, 10.04it/s, mccloss - 0.8461, iou_score - 0.06613, accuracy - 0.7378, precision - 0.06701, recall - 0.87, fscore - 0.121]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.85it/s, mccloss - 0.9747, iou_score - 0.04565, accuracy - 0.8414, precision - 0.04876, recall - 0.7938, fscore - 0.07649]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:05<00:00, 10.49it/s, mccloss - 0.8107, iou_score - 0.1053, accuracy - 0.8402, precision - 0.1082, recall - 0.7936, fscore - 0.1813]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.83it/s, mccloss - 0.9985, iou_score - 0.5625, accuracy - 0.9845, precision - 0.9931, recall - 0.5625, fscore - 0.5625]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:05<00:00, 10.19it/s, mccloss - 0.7544, iou_score - 0.1522, accuracy - 0.8949, precision - 0.1579, recall - 0.82, fscore - 0.2485]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.22it/s, mccloss - 0.9974, iou_score - 0.5556, accuracy - 0.9845, precision - 0.9931, recall - 0.5625, fscore - 0.5556]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:05<00:00, 10.32it/s, mccloss - 0.7339, iou_score - 0.2051, accuracy - 0.9408, precision - 0.235, recall - 0.6596, fscore - 0.3144]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.35it/s, mccloss - 0.977, iou_score - 0.4458, accuracy - 0.9752, precision - 0.8205, recall - 0.5917, fscore - 0.4526]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:05<00:00, 10.18it/s, mccloss - 0.6939, iou_score - 0.2223, accuracy - 0.9468, precision - 0.2522, recall - 0.6595, fscore - 0.335]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.91it/s, mccloss - 0.9989, iou_score - 0.5417, accuracy - 0.9841, precision - 0.9583, recall - 0.5626, fscore - 0.5418]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:05<00:00, 10.44it/s, mccloss - 0.6303, iou_score - 0.2713, accuracy - 0.9589, precision - 0.3184, recall - 0.6959, fscore - 0.399]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.50it/s, mccloss - 0.8908, iou_score - 0.5003, accuracy - 0.9752, precision - 0.7468, recall - 0.6925, fscore - 0.5267]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:05<00:00, 10.60it/s, mccloss - 0.6223, iou_score - 0.2729, accuracy - 0.9612, precision - 0.3293, recall - 0.6614, fscore - 0.3956]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.32it/s, mccloss - 0.9986, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:05<00:00,  9.91it/s, mccloss - 0.6091, iou_score - 0.2852, accuracy - 0.9663, precision - 0.3609, recall - 0.6306, fscore - 0.4085]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.77it/s, mccloss - 0.9609, iou_score - 0.5003, accuracy - 0.984, precision - 0.8842, recall - 0.593, fscore - 0.5116]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:05<00:00, 10.55it/s, mccloss - 0.5961, iou_score - 0.2904, accuracy - 0.9687, precision - 0.3778, recall - 0.602, fscore - 0.4162]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.69it/s, mccloss - 0.8443, iou_score - 0.4853, accuracy - 0.9789, precision - 0.6807, recall - 0.7407, fscore - 0.5178]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:05<00:00, 10.15it/s, mccloss - 0.5787, iou_score - 0.3067, accuracy - 0.9716, precision - 0.4048, recall - 0.5968, fscore - 0.4358]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.75it/s, mccloss - 0.8751, iou_score - 0.4248, accuracy - 0.9631, precision - 0.6207, recall - 0.7069, fscore - 0.4545]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:05<00:00, 10.65it/s, mccloss - 0.5624, iou_score - 0.3212, accuracy - 0.9733, precision - 0.4238, recall - 0.6051, fscore - 0.4487]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.17it/s, mccloss - 0.8328, iou_score - 0.3938, accuracy - 0.9762, precision - 0.5473, recall - 0.7682, fscore - 0.4326]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:05<00:00, 10.54it/s, mccloss - 0.5416, iou_score - 0.3445, accuracy - 0.9769, precision - 0.4628, recall - 0.6033, fscore - 0.4727]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.36it/s, mccloss - 0.8276, iou_score - 0.3607, accuracy - 0.9741, precision - 0.5202, recall - 0.7592, fscore - 0.3959]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:05<00:00, 10.02it/s, mccloss - 0.5412, iou_score - 0.3405, accuracy - 0.9796, precision - 0.542, recall - 0.5711, fscore - 0.4692]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.07it/s, mccloss - 0.8346, iou_score - 0.4559, accuracy - 0.9755, precision - 0.6155, recall - 0.7647, fscore - 0.4941]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:05<00:00, 10.61it/s, mccloss - 0.5507, iou_score - 0.3183, accuracy - 0.9749, precision - 0.451, recall - 0.5828, fscore - 0.4502]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.18it/s, mccloss - 0.8562, iou_score - 0.5209, accuracy - 0.9845, precision - 0.7719, recall - 0.6996, fscore - 0.5464]
# No improvement in 7 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:05<00:00, 10.12it/s, mccloss - 0.572, iou_score - 0.3227, accuracy - 0.9801, precision - 0.5248, recall - 0.479, fscore - 0.4387]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.56it/s, mccloss - 0.8375, iou_score - 0.4343, accuracy - 0.9779, precision - 0.607, recall - 0.7498, fscore - 0.4686]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:05<00:00,  9.84it/s, mccloss - 0.4859, iou_score - 0.3851, accuracy - 0.9809, precision - 0.5277, recall - 0.6195, fscore - 0.5202]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.35it/s, mccloss - 0.8326, iou_score - 0.444, accuracy - 0.9775, precision - 0.5874, recall - 0.761, fscore - 0.4793]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:05<00:00, 10.19it/s, mccloss - 0.4959, iou_score - 0.3744, accuracy - 0.979, precision - 0.4997, recall - 0.6285, fscore - 0.5096]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.87it/s, mccloss - 0.8286, iou_score - 0.449, accuracy - 0.9792, precision - 0.6091, recall - 0.757, fscore - 0.4843]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:05<00:00, 10.37it/s, mccloss - 0.463, iou_score - 0.4262, accuracy - 0.9823, precision - 0.6018, recall - 0.6171, fscore - 0.5622]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.55it/s, mccloss - 0.8309, iou_score - 0.4738, accuracy - 0.98, precision - 0.6381, recall - 0.7597, fscore - 0.5094]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:05<00:00, 10.62it/s, mccloss - 0.489, iou_score - 0.3789, accuracy - 0.9819, precision - 0.5429, recall - 0.5996, fscore - 0.5169]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.74it/s, mccloss - 0.8311, iou_score - 0.4374, accuracy - 0.9764, precision - 0.6063, recall - 0.7602, fscore - 0.4736]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:05<00:00, 10.64it/s, mccloss - 0.5046, iou_score - 0.3877, accuracy - 0.9811, precision - 0.5873, recall - 0.5752, fscore - 0.5195]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.91it/s, mccloss - 0.8324, iou_score - 0.458, accuracy - 0.9783, precision - 0.624, recall - 0.7577, fscore - 0.4935]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:05<00:00, 10.38it/s, mccloss - 0.4842, iou_score - 0.3849, accuracy - 0.9827, precision - 0.6052, recall - 0.6, fscore - 0.5208]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.57it/s, mccloss - 0.8288, iou_score - 0.4911, accuracy - 0.9805, precision - 0.6681, recall - 0.7584, fscore - 0.5264]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:05<00:00, 10.49it/s, mccloss - 0.4831, iou_score - 0.4061, accuracy - 0.9821, precision - 0.5906, recall - 0.5942, fscore - 0.5416]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.71it/s, mccloss - 0.8302, iou_score - 0.5105, accuracy - 0.9818, precision - 0.6892, recall - 0.7552, fscore - 0.5457]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:05<00:00, 10.75it/s, mccloss - 0.4648, iou_score - 0.4299, accuracy - 0.9837, precision - 0.631, recall - 0.5816, fscore - 0.5625]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.26it/s, mccloss - 0.8317, iou_score - 0.4942, accuracy - 0.981, precision - 0.6768, recall - 0.7579, fscore - 0.5298]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:05<00:00, 10.03it/s, mccloss - 0.4641, iou_score - 0.4299, accuracy - 0.984, precision - 0.6471, recall - 0.5927, fscore - 0.5636]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.04it/s, mccloss - 0.8305, iou_score - 0.5519, accuracy - 0.9837, precision - 0.7491, recall - 0.7508, fscore - 0.5866]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:05<00:00, 10.49it/s, mccloss - 0.4827, iou_score - 0.4119, accuracy - 0.9836, precision - 0.6319, recall - 0.5687, fscore - 0.5426]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.54it/s, mccloss - 0.8322, iou_score - 0.4786, accuracy - 0.9793, precision - 0.6439, recall - 0.7649, fscore - 0.5148]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 27
# train: 100%|██████████| 56/56 [00:05<00:00, 10.36it/s, mccloss - 0.4495, iou_score - 0.4354, accuracy - 0.9819, precision - 0.5961, recall - 0.6598, fscore - 0.5733]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.29it/s, mccloss - 0.8295, iou_score - 0.4898, accuracy - 0.9813, precision - 0.657, recall - 0.7616, fscore - 0.5251]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 28
# train: 100%|██████████| 56/56 [00:05<00:00, 10.17it/s, mccloss - 0.4566, iou_score - 0.4512, accuracy - 0.9832, precision - 0.6396, recall - 0.6119, fscore - 0.5863]
# valid: 100%|██████████| 144/144 [00:03<00:00, 37.84it/s, mccloss - 0.8332, iou_score - 0.4584, accuracy - 0.9792, precision - 0.6215, recall - 0.7563, fscore - 0.4936]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 29
# train: 100%|██████████| 56/56 [00:05<00:00, 10.44it/s, mccloss - 0.4699, iou_score - 0.4142, accuracy - 0.9823, precision - 0.5617, recall - 0.6278, fscore - 0.5513]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.33it/s, mccloss - 0.8308, iou_score - 0.4879, accuracy - 0.9821, precision - 0.6727, recall - 0.7517, fscore - 0.5221]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 30
# train: 100%|██████████| 56/56 [00:05<00:00, 10.07it/s, mccloss - 0.4526, iou_score - 0.4356, accuracy - 0.9831, precision - 0.6421, recall - 0.6184, fscore - 0.5722]
# valid: 100%|██████████| 144/144 [00:03<00:00, 38.96it/s, mccloss - 0.8319, iou_score - 0.5227, accuracy - 0.9836, precision - 0.7131, recall - 0.7462, fscore - 0.5562]
# No improvement in 5 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:05<00:00, 10.69it/s, mccloss - 0.8112, iou_score - 0.1525, accuracy - 0.8635, precision - 0.1559, recall - 0.8854, fscore - 0.2517]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.52it/s, mccloss - 0.9188, iou_score - 0.4302, accuracy - 0.9561, precision - 0.5657, recall - 0.7814, fscore - 0.4656]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:05<00:00,  9.91it/s, mccloss - 0.7371, iou_score - 0.1959, accuracy - 0.9007, precision - 0.2035, recall - 0.885, fscore - 0.3099]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.02it/s, mccloss - 0.9173, iou_score - 0.08092, accuracy - 0.6821, precision - 0.0812, recall - 0.9537, fscore - 0.114]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:05<00:00, 10.45it/s, mccloss - 0.7003, iou_score - 0.2501, accuracy - 0.9347, precision - 0.2697, recall - 0.8072, fscore - 0.3696]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.63it/s, mccloss - 0.8563, iou_score - 0.4538, accuracy - 0.9645, precision - 0.5051, recall - 0.8695, fscore - 0.5051]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:05<00:00,  9.99it/s, mccloss - 0.6521, iou_score - 0.2694, accuracy - 0.9443, precision - 0.2957, recall - 0.8247, fscore - 0.3987]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.46it/s, mccloss - 0.8409, iou_score - 0.6027, accuracy - 0.9814, precision - 0.6982, recall - 0.8236, fscore - 0.6477]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:05<00:00, 10.08it/s, mccloss - 0.5972, iou_score - 0.3223, accuracy - 0.9549, precision - 0.3595, recall - 0.8071, fscore - 0.4558]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.92it/s, mccloss - 0.8217, iou_score - 0.3916, accuracy - 0.9594, precision - 0.4267, recall - 0.8941, fscore - 0.4456]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:05<00:00, 10.10it/s, mccloss - 0.5616, iou_score - 0.3398, accuracy - 0.96, precision - 0.3857, recall - 0.8221, fscore - 0.4774]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.68it/s, mccloss - 0.8424, iou_score - 0.4764, accuracy - 0.9685, precision - 0.614, recall - 0.7897, fscore - 0.516]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:05<00:00, 10.09it/s, mccloss - 0.5248, iou_score - 0.3726, accuracy - 0.9684, precision - 0.4359, recall - 0.7868, fscore - 0.5135]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.16it/s, mccloss - 0.8152, iou_score - 0.6387, accuracy - 0.9863, precision - 0.8092, recall - 0.8, fscore - 0.6791]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:05<00:00, 10.41it/s, mccloss - 0.4878, iou_score - 0.3994, accuracy - 0.9716, precision - 0.4782, recall - 0.7801, fscore - 0.5435]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.97it/s, mccloss - 0.7941, iou_score - 0.4647, accuracy - 0.9661, precision - 0.5309, recall - 0.8598, fscore - 0.5152]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:05<00:00,  9.71it/s, mccloss - 0.5132, iou_score - 0.3685, accuracy - 0.9719, precision - 0.4611, recall - 0.7232, fscore - 0.512]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.63it/s, mccloss - 0.8569, iou_score - 0.1782, accuracy - 0.8865, precision - 0.1864, recall - 0.8986, fscore - 0.2248]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:05<00:00,  9.98it/s, mccloss - 0.4906, iou_score - 0.3816, accuracy - 0.9693, precision - 0.4608, recall - 0.7584, fscore - 0.5192]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.84it/s, mccloss - 0.8799, iou_score - 0.6182, accuracy - 0.9832, precision - 0.8634, recall - 0.7149, fscore - 0.6478]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:05<00:00, 10.15it/s, mccloss - 0.4632, iou_score - 0.4047, accuracy - 0.9727, precision - 0.5027, recall - 0.7657, fscore - 0.5479]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.97it/s, mccloss - 0.8322, iou_score - 0.6533, accuracy - 0.9887, precision - 0.8866, recall - 0.7413, fscore - 0.6847]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:05<00:00, 10.22it/s, mccloss - 0.4801, iou_score - 0.3839, accuracy - 0.9709, precision - 0.4823, recall - 0.735, fscore - 0.5244]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.76it/s, mccloss - 0.8153, iou_score - 0.2534, accuracy - 0.935, precision - 0.2645, recall - 0.8958, fscore - 0.307]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:05<00:00,  9.89it/s, mccloss - 0.4872, iou_score - 0.3913, accuracy - 0.9765, precision - 0.5616, recall - 0.6657, fscore - 0.5256]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.83it/s, mccloss - 0.8564, iou_score - 0.614, accuracy - 0.9854, precision - 0.8535, recall - 0.7239, fscore - 0.6475]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:05<00:00, 10.22it/s, mccloss - 0.4394, iou_score - 0.4275, accuracy - 0.9777, precision - 0.5451, recall - 0.7379, fscore - 0.5743]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.75it/s, mccloss - 0.8625, iou_score - 0.6593, accuracy - 0.9874, precision - 0.9203, recall - 0.7137, fscore - 0.6894]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:05<00:00, 10.15it/s, mccloss - 0.4632, iou_score - 0.4034, accuracy - 0.9773, precision - 0.5374, recall - 0.684, fscore - 0.5441]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.66it/s, mccloss - 0.8393, iou_score - 0.6506, accuracy - 0.9882, precision - 0.9053, recall - 0.7168, fscore - 0.6836]
# No improvement in 1 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:05<00:00, 10.26it/s, mccloss - 0.4017, iou_score - 0.4575, accuracy - 0.9799, precision - 0.5954, recall - 0.7552, fscore - 0.6045]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.46it/s, mccloss - 0.7768, iou_score - 0.6122, accuracy - 0.987, precision - 0.7629, recall - 0.8059, fscore - 0.653]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:05<00:00, 10.02it/s, mccloss - 0.3803, iou_score - 0.4981, accuracy - 0.9837, precision - 0.6763, recall - 0.7061, fscore - 0.6371]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.52it/s, mccloss - 0.7712, iou_score - 0.6087, accuracy - 0.9868, precision - 0.7446, recall - 0.8149, fscore - 0.6516]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:05<00:00,  9.99it/s, mccloss - 0.3682, iou_score - 0.532, accuracy - 0.9856, precision - 0.7117, recall - 0.7367, fscore - 0.6665]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.01it/s, mccloss - 0.7643, iou_score - 0.5642, accuracy - 0.985, precision - 0.6833, recall - 0.8364, fscore - 0.6097]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:05<00:00,  9.79it/s, mccloss - 0.3647, iou_score - 0.544, accuracy - 0.9837, precision - 0.7415, recall - 0.72, fscore - 0.6879]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.55it/s, mccloss - 0.7935, iou_score - 0.6518, accuracy - 0.9883, precision - 0.8469, recall - 0.7774, fscore - 0.6889]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:05<00:00,  9.73it/s, mccloss - 0.383, iou_score - 0.5132, accuracy - 0.985, precision - 0.7084, recall - 0.7005, fscore - 0.648]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.79it/s, mccloss - 0.7738, iou_score - 0.6552, accuracy - 0.9882, precision - 0.8202, recall - 0.8048, fscore - 0.6976]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:05<00:00, 10.16it/s, mccloss - 0.379, iou_score - 0.5222, accuracy - 0.9849, precision - 0.723, recall - 0.6983, fscore - 0.6514]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.67it/s, mccloss - 0.7601, iou_score - 0.6375, accuracy - 0.9863, precision - 0.7426, recall - 0.8396, fscore - 0.6834]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:05<00:00,  9.70it/s, mccloss - 0.3495, iou_score - 0.5374, accuracy - 0.9856, precision - 0.7157, recall - 0.7433, fscore - 0.6665]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.50it/s, mccloss - 0.7609, iou_score - 0.6331, accuracy - 0.9872, precision - 0.7422, recall - 0.829, fscore - 0.6777]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:05<00:00, 10.12it/s, mccloss - 0.3587, iou_score - 0.5184, accuracy - 0.985, precision - 0.69, recall - 0.742, fscore - 0.6535]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.77it/s, mccloss - 0.7708, iou_score - 0.622, accuracy - 0.9875, precision - 0.7507, recall - 0.8094, fscore - 0.6633]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:05<00:00, 10.27it/s, mccloss - 0.3417, iou_score - 0.5511, accuracy - 0.9853, precision - 0.7188, recall - 0.7521, fscore - 0.6911]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.09it/s, mccloss - 0.7725, iou_score - 0.6344, accuracy - 0.988, precision - 0.7775, recall - 0.8007, fscore - 0.6758]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:05<00:00, 10.48it/s, mccloss - 0.3204, iou_score - 0.5974, accuracy - 0.9862, precision - 0.7711, recall - 0.773, fscore - 0.7298]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.13it/s, mccloss - 0.7577, iou_score - 0.6133, accuracy - 0.9863, precision - 0.7135, recall - 0.8339, fscore - 0.6589]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:05<00:00,  9.97it/s, mccloss - 0.3349, iou_score - 0.5497, accuracy - 0.9864, precision - 0.7411, recall - 0.7489, fscore - 0.683]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.12it/s, mccloss - 0.7773, iou_score - 0.6376, accuracy - 0.9879, precision - 0.7789, recall - 0.7958, fscore - 0.6793]
# No improvement in 6 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training

# %%
print('All processing complete!')
