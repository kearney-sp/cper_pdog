# %%
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
#os.environ['LD_LIBRARY_PATH']= '$LD_LIBRARY_PATH:/usr/local/cuda/extras/CUPTI/lib64'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prep lists of input files

# %%
from glob import glob
import re
import pandas as pd
from random import sample, seed

# %%
encoder_list = ['resnet34']
avail_suffix = ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']

# %%
# set working directory
os.chdir('/project/cper_neon_aop/cper_pdog_uas')

# set directories for training data and labels
DATA_FOLDER = './cnn_train_images/{}_{}.tif'
LABEL_FOLDER = './cnn_train_labels/{}_labels.tif'

# %%
# read in csvs with training information
df_tiles = pd.read_csv('train_tiles/train_bboxes_all_assigned.csv')
df_polys = pd.read_csv('train_polys/train_polys_all.csv')

# %%
# get all ids to be used
label_files = glob(LABEL_FOLDER.replace('{}', '*'))
all_ids = [re.sub('_labels.tif', '', os.path.basename(f)) for f in label_files]
all_tiles = list(set(['_'.join(y.split('_')[2:]) for y in all_ids]))

# %%
# separate training and test data and get paths to files
all_files = glob(DATA_FOLDER.replace('{}', '*'))
all_train_tiles = [x for x in df_tiles.apply(lambda x: '_'.join([x.Pasture, x.Tile]) if x.Train == 1 else '', axis=1) if x != '' and x in all_tiles]
test_tiles = list(set(all_tiles) - set(all_train_tiles))

all_train_ids = [x for x in all_ids if '_'.join(x.split('_')[-3:]) in all_train_tiles]
test_ids = list(set(all_ids) - set(all_train_ids))

seed(321)
valid_ids = sample(all_train_ids, int(np.ceil(len(all_train_ids)*0.3)))
train_ids = list(set(all_train_ids) - set(valid_ids))

train_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in train_ids]
valid_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in valid_ids]
test_files = [f for f in all_files if '_'.join(os.path.basename(f).split('_')[:-1]) in test_ids]

# %%
tile_ids = df_tiles[(df_tiles['trainer'] != 'Nick') &
                    (df_tiles['Digitize'] == 1)].apply(lambda x: '_'.join([x.Pasture, x.Tile]), axis=1)
#all_tiles#
[x for x in all_tiles if x not in tile_ids.to_list()]
# Out:
# []

# %%
[x for x in tile_ids.to_list() if x not in all_tiles]
# Out:
# []

# %% [markdown]
# ### Dataloader
# Writing helper class for data extraction, tranformation and preprocessing

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset
from skimage import io

# %%
class Dataset(BaseDataset):
    """Read images, apply augmentation and preprocessing transformations.
    
    Args:
        ids (list): list of unique ids for all images
        images_path (str): path to data images
        masks_path (str): path to label masks
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    
    CLASSES = ['other', 'burrow']
    
    def __init__(
            self, 
            ids,
            suffix_list,
            images_path,
            masks_path, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
            suffix_dict = {
        'rgb': {'channels': 3,
                'dtype': 'uint8'},
        'tpi': {'channels': 1,
                'dtype': 'float32'},
        'dsm': {'channels': 1,
                'dtype': 'float32'},
        'shade': {'channels': 1,
                  'dtype': 'float32'},
        'ndvi': {'channels': 1,
                  'dtype': 'float32'}
    }
    ):
        # get IDs as attribute
        self.ids = ids
        
        # get suffix info
        self.suffix_dict = suffix_dict
        
        # get list of suffixes as attribute
        self.suffix_list = suffix_list
        
        # List of files
        self.images_fps = []
        self.masks_fps = [masks_path.format(id) for id in ids]
        for id in ids:
            self.images_fps.append({s: images_path.format(id, s) for s in suffix_list})
            
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image_list = []
        self.image_dict = {}
        for s in self.suffix_list:
            image_s = np.asarray(io.imread(self.images_fps[i][s]), dtype=self.suffix_dict[s]['dtype'])
            if len(image_s.shape) == 2:
                image_s = np.expand_dims(image_s, axis=-1)
            image_s[np.isnan(image_s)] = 0
            image_list.append(image_s)
            self.image_dict[s] = image_s
        if len(image_list) == 1:
            image = image_list[0]
        else:
            image = np.concatenate(image_list, axis=-1)
        mask = np.asarray(io.imread(self.masks_fps[i]), dtype='float32')
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1)#.astype('float32')
        #print('fetched: ', self.ids[i])
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        else:
            image = torch.from_numpy(image.transpose(2, 0, 1).astype('float32'))
            mask = torch.from_numpy(mask.transpose(2, 0, 1).astype('float32'))
        return image, mask
        
    def __len__(self):
        return len(self.ids)

# %% [markdown]
# ### Augmentations

# %%
import albumentations as albu
import random

# %%
def get_training_augmentation():
    win_size = 32 * random.randint(7, 10)
    train_transform = [

        albu.HorizontalFlip(p=0.5),
        albu.VerticalFlip(p=0.5),

        #albu.ShiftScaleRotate(scale_limit=0.0, rotate_limit=45, shift_limit=0.1, p=1, border_mode=0),

        #albu.PadIfNeeded(min_height=win_size, min_width=win_size, always_apply=True, border_mode=4),
        albu.RandomCrop(height=win_size, width=win_size, always_apply=True),

        #albu.GaussNoise(p=0.2, var_limit=1.0),
        #albu.Perspective(p=0.5),

        #albu.OneOf(
        #    [
        #        #albu.CLAHE(p=1), # required int8 images
        #        albu.RandomBrightnessContrast(p=1),
        #        #albu.RandomGamma(p=1),
        #        #albu.HueSaturationValue(p=1),
        #    ],
        #    p=0.9,
        #),

        albu.OneOf(
            [
                albu.Sharpen(p=1),
                albu.Blur(blur_limit=(3, 7), p=1),
                albu.MotionBlur(blur_limit=(3, 7), p=1),
            ],
            p=0.25,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.PadIfNeeded(384, 480)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %% [markdown]
# ### Create and train model

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils
import torch.nn as nn
import gc

# %%
ENCODER = 'resnet34'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['burrow']
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #'cuda'# 'cpu'# 
USE_PARALLEL = True

# %%
import itertools
#list(itertools.combinations(avail_suffix, len(avail_suffix)))
suffix_combinations = list()
for n in range(1, len(avail_suffix) + 1):
    suffix_combinations += list(itertools.combinations(avail_suffix, n))

# %%
outDIR = './cnn_results_manet/'
if not os.path.exists(outDIR):
    os.mkdir(outDIR)

# %%
for suffix_sub in suffix_combinations:
    suffix_list = list(suffix_sub)
    print('\n\n----------------------------------------------------------')
    print(suffix_list)
    if os.path.exists(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt'):
        print('skipping - already trained.')
        continue
    else:
        train_dataset = Dataset(
            train_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            augmentation=get_training_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)

        valid_dataset = Dataset(
            valid_ids,
            suffix_list,
            DATA_FOLDER,
            LABEL_FOLDER,
            #augmentation=get_validation_augmentation(),
            #preprocessing=get_preprocessing(preprocessing_fn),
            classes=CLASSES)


        train_loader = DataLoader(train_dataset, batch_size=6, shuffle=False,
                                  drop_last=True, num_workers=6, pin_memory=False)
        valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=6, pin_memory=False)

        # create segmentation model with pretrained encoder
        model = smp.MAnet(
            encoder_name=ENCODER, 
            encoder_weights=ENCODER_WEIGHTS, 
            classes=len(CLASSES), 
            activation=ACTIVATION,
            in_channels=train_dataset[0][0].shape[0],
        )
        
        if USE_PARALLEL:
            model = nn.DataParallel(model)

        preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

        # Dice/F1 score - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
        # IoU/Jaccard score - https://en.wikipedia.org/wiki/Jaccard_index

        loss = smp.losses.MCCLoss()
        loss.__name__ = 'mccloss'
        metrics = [
            utils.metrics.IoU(threshold=0.5),
            utils.metrics.Accuracy(threshold=0.5),
            utils.metrics.Precision(threshold=0.5),
            utils.metrics.Recall(threshold=0.5),
            utils.metrics.Fscore(threshold=0.5)
        ]

        optimizer = torch.optim.Adam([ 
            dict(params=model.parameters(), lr=0.0001),
        ])

        # create epoch runners 
        # it is a simple loop of iterating over dataloader`s samples
        train_epoch = utils.train.TrainEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            optimizer=optimizer,
            device=DEVICE,
            verbose=True,
        )

        valid_epoch = utils.train.ValidEpoch(
            model, 
            loss=loss, 
            metrics=metrics, 
            device=DEVICE,
            verbose=True,
        )

        # train model for up to 60 epochs

        max_score = 0
        max_score_train = 0
        no_improve = 0

        for i in range(1, 61):

            print('\nEpoch: {}'.format(i))
            train_logs = train_epoch.run(train_loader)
            valid_logs = valid_epoch.run(valid_loader)

            # do something (save model, change lr, etc.)
            if max_score < valid_logs['fscore']:
                max_score = valid_logs['fscore']
                max_score_train = train_logs['fscore']
                torch.save(model, outDIR + 'best_model_' + '_'.join(suffix_list) + '.pth')
                valid_logs['best_epoch'] = i
                best_valid_logs = valid_logs.copy()
                print('Model saved!')
                no_improve = 0
            else:
                no_improve += 1
                print('No improvement in ' + str(no_improve) + ' epochs. Model not saved.')

            if i > 15:
                if no_improve >= 5:
                    if (train_logs['fscore'] - max_score_train) < 0.05:
                        print('More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
                    elif (train_logs['fscore'] - max_score_train) < 0.10 and no_improve == 15:
                        print('15 epochs without validation improvement while learning rate <= 1e-5...ending training')
                        with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        break
            if i == 60:
                with open(outDIR + 'best_model_' + '_'.join(suffix_list) + '_validation.txt','w') as data: 
                            data.write(str(best_valid_logs))
                        
            if i%15 == 0:
                no_improve = 0
                optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr'] * 0.1
                print('Decrease decoder learning rate by factor of 10')

        del model, train_epoch, valid_epoch
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# ----------------------------------------------------------
# ['rgb']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['shade', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'ndvi']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['rgb', 'shade', 'ndvi', 'dsm']
# skipping - already trained.
#
#
# ----------------------------------------------------------
# ['tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:10<00:00,  5.35it/s, mccloss - 0.929, iou_score - 0.03689, accuracy - 0.575, precision - 0.0372, recall - 0.8481, fscore - 0.06995]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.14it/s, mccloss - 0.9633, iou_score - 0.02435, accuracy - 0.5094, precision - 0.02452, recall - 0.8795, fscore - 0.04426]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:06<00:00,  8.52it/s, mccloss - 0.8846, iou_score - 0.06674, accuracy - 0.7846, precision - 0.06765, recall - 0.8281, fscore - 0.1215]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.23it/s, mccloss - 0.9573, iou_score - 0.03082, accuracy - 0.6338, precision - 0.03108, recall - 0.8549, fscore - 0.05426]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:06<00:00,  8.66it/s, mccloss - 0.859, iou_score - 0.08727, accuracy - 0.8433, precision - 0.08911, recall - 0.8112, fscore - 0.1546]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.41it/s, mccloss - 0.9411, iou_score - 0.0409, accuracy - 0.7204, precision - 0.0414, recall - 0.8434, fscore - 0.0689]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:06<00:00,  9.04it/s, mccloss - 0.8341, iou_score - 0.1039, accuracy - 0.8742, precision - 0.107, recall - 0.7871, fscore - 0.1792]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.88it/s, mccloss - 0.9335, iou_score - 0.04529, accuracy - 0.7565, precision - 0.04601, recall - 0.8371, fscore - 0.07477]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:06<00:00,  8.39it/s, mccloss - 0.8022, iou_score - 0.1311, accuracy - 0.9017, precision - 0.1371, recall - 0.7793, fscore - 0.2203]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.00it/s, mccloss - 0.9103, iou_score - 0.06547, accuracy - 0.847, precision - 0.0683, recall - 0.8324, fscore - 0.1023]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:06<00:00,  8.78it/s, mccloss - 0.7629, iou_score - 0.172, accuracy - 0.9337, precision - 0.1857, recall - 0.781, fscore - 0.2784]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.46it/s, mccloss - 0.9987, iou_score - 0.5016, accuracy - 0.9818, precision - 0.9187, recall - 0.5662, fscore - 0.5026]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:06<00:00,  8.41it/s, mccloss - 0.7644, iou_score - 0.1626, accuracy - 0.9293, precision - 0.1754, recall - 0.7075, fscore - 0.2621]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.11it/s, mccloss - 0.8846, iou_score - 0.3438, accuracy - 0.955, precision - 0.4613, recall - 0.7756, fscore - 0.3818]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:06<00:00,  9.12it/s, mccloss - 0.7091, iou_score - 0.2145, accuracy - 0.9526, precision - 0.2404, recall - 0.7253, fscore - 0.3328]
# valid: 100%|██████████| 144/144 [00:03<00:00, 36.20it/s, mccloss - 0.9594, iou_score - 0.5656, accuracy - 0.9849, precision - 0.9386, recall - 0.6034, fscore - 0.5839]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:06<00:00,  8.63it/s, mccloss - 0.6857, iou_score - 0.2216, accuracy - 0.9565, precision - 0.2492, recall - 0.7219, fscore - 0.3427]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.62it/s, mccloss - 0.9239, iou_score - 0.5531, accuracy - 0.9858, precision - 0.8794, recall - 0.6447, fscore - 0.5735]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:06<00:00,  9.13it/s, mccloss - 0.6649, iou_score - 0.2452, accuracy - 0.9644, precision - 0.2934, recall - 0.6812, fscore - 0.3715]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.58it/s, mccloss - 0.8795, iou_score - 0.6105, accuracy - 0.9851, precision - 0.8649, recall - 0.7161, fscore - 0.6417]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:06<00:00,  8.58it/s, mccloss - 0.6408, iou_score - 0.2626, accuracy - 0.968, precision - 0.3163, recall - 0.6687, fscore - 0.3898]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.22it/s, mccloss - 1.0, iou_score - 0.5556, accuracy - 0.9845, precision - 0.9861, recall - 0.5625, fscore - 0.5556]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:06<00:00,  8.56it/s, mccloss - 0.5845, iou_score - 0.3126, accuracy - 0.9745, precision - 0.3828, recall - 0.7069, fscore - 0.4473]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.15it/s, mccloss - 1.0, iou_score - 0.5625, accuracy - 0.9846, precision - 1.0, recall - 0.5625, fscore - 0.5625]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:06<00:00,  8.59it/s, mccloss - 0.6089, iou_score - 0.283, accuracy - 0.9731, precision - 0.3505, recall - 0.6495, fscore - 0.4118]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.22it/s, mccloss - 0.87, iou_score - 0.5728, accuracy - 0.9836, precision - 0.8061, recall - 0.7209, fscore - 0.6015]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:06<00:00,  8.61it/s, mccloss - 0.5822, iou_score - 0.3096, accuracy - 0.9762, precision - 0.4191, recall - 0.6396, fscore - 0.4408]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.90it/s, mccloss - 0.8449, iou_score - 0.5479, accuracy - 0.9829, precision - 0.7442, recall - 0.7526, fscore - 0.5838]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:06<00:00,  8.20it/s, mccloss - 0.5645, iou_score - 0.3325, accuracy - 0.9778, precision - 0.4595, recall - 0.6358, fscore - 0.4617]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.53it/s, mccloss - 0.8898, iou_score - 0.609, accuracy - 0.9869, precision - 0.9172, recall - 0.6688, fscore - 0.6334]
# No improvement in 5 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:06<00:00,  8.86it/s, mccloss - 0.529, iou_score - 0.3652, accuracy - 0.9822, precision - 0.5271, recall - 0.6296, fscore - 0.501]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.54it/s, mccloss - 0.8397, iou_score - 0.5339, accuracy - 0.9792, precision - 0.6816, recall - 0.7726, fscore - 0.5718]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:06<00:00,  8.33it/s, mccloss - 0.5189, iou_score - 0.3753, accuracy - 0.9837, precision - 0.536, recall - 0.6397, fscore - 0.5084]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.30it/s, mccloss - 0.84, iou_score - 0.5338, accuracy - 0.9786, precision - 0.6881, recall - 0.7727, fscore - 0.5716]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:06<00:00,  8.93it/s, mccloss - 0.4916, iou_score - 0.4165, accuracy - 0.985, precision - 0.5705, recall - 0.649, fscore - 0.5489]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.97it/s, mccloss - 0.8421, iou_score - 0.5389, accuracy - 0.9802, precision - 0.6984, recall - 0.7667, fscore - 0.576]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:06<00:00,  8.37it/s, mccloss - 0.5102, iou_score - 0.3889, accuracy - 0.9842, precision - 0.5537, recall - 0.6346, fscore - 0.5222]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.60it/s, mccloss - 0.8387, iou_score - 0.4867, accuracy - 0.9786, precision - 0.6449, recall - 0.7693, fscore - 0.5244]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:06<00:00,  8.88it/s, mccloss - 0.4792, iou_score - 0.4259, accuracy - 0.9859, precision - 0.5887, recall - 0.6628, fscore - 0.5544]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.39it/s, mccloss - 0.841, iou_score - 0.5553, accuracy - 0.9824, precision - 0.73, recall - 0.7602, fscore - 0.5913]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:06<00:00,  8.55it/s, mccloss - 0.4876, iou_score - 0.4136, accuracy - 0.9844, precision - 0.5791, recall - 0.6537, fscore - 0.5457]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.37it/s, mccloss - 0.8423, iou_score - 0.5532, accuracy - 0.9813, precision - 0.724, recall - 0.7633, fscore - 0.5895]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:06<00:00,  8.29it/s, mccloss - 0.4926, iou_score - 0.4125, accuracy - 0.9857, precision - 0.559, recall - 0.6399, fscore - 0.5391]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.48it/s, mccloss - 0.8396, iou_score - 0.5211, accuracy - 0.98, precision - 0.6921, recall - 0.7646, fscore - 0.5575]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 23
# train: 100%|██████████| 56/56 [00:06<00:00,  8.24it/s, mccloss - 0.4801, iou_score - 0.4219, accuracy - 0.9861, precision - 0.5952, recall - 0.6495, fscore - 0.5518]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.75it/s, mccloss - 0.84, iou_score - 0.5218, accuracy - 0.98, precision - 0.6906, recall - 0.7658, fscore - 0.5574]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 24
# train: 100%|██████████| 56/56 [00:06<00:00,  8.32it/s, mccloss - 0.4763, iou_score - 0.439, accuracy - 0.9855, precision - 0.6041, recall - 0.6576, fscore - 0.5717]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.61it/s, mccloss - 0.84, iou_score - 0.5263, accuracy - 0.9793, precision - 0.6846, recall - 0.7696, fscore - 0.5635]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 25
# train: 100%|██████████| 56/56 [00:06<00:00,  9.31it/s, mccloss - 0.4728, iou_score - 0.4197, accuracy - 0.9846, precision - 0.5438, recall - 0.6857, fscore - 0.5549]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.93it/s, mccloss - 0.8385, iou_score - 0.5586, accuracy - 0.9827, precision - 0.7483, recall - 0.7565, fscore - 0.594]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 26
# train: 100%|██████████| 56/56 [00:06<00:00,  8.97it/s, mccloss - 0.4744, iou_score - 0.4397, accuracy - 0.9861, precision - 0.5803, recall - 0.664, fscore - 0.5707]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.04it/s, mccloss - 0.8379, iou_score - 0.5303, accuracy - 0.9814, precision - 0.7122, recall - 0.7651, fscore - 0.5658]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 27
# train: 100%|██████████| 56/56 [00:06<00:00,  8.15it/s, mccloss - 0.4444, iou_score - 0.4544, accuracy - 0.9868, precision - 0.6175, recall - 0.694, fscore - 0.5852]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.51it/s, mccloss - 0.8416, iou_score - 0.5633, accuracy - 0.9834, precision - 0.7615, recall - 0.7554, fscore - 0.5972]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 28
# train: 100%|██████████| 56/56 [00:06<00:00,  8.27it/s, mccloss - 0.4587, iou_score - 0.4328, accuracy - 0.9859, precision - 0.5833, recall - 0.6792, fscore - 0.5653]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.29it/s, mccloss - 0.843, iou_score - 0.541, accuracy - 0.9823, precision - 0.7201, recall - 0.7533, fscore - 0.575]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 29
# train: 100%|██████████| 56/56 [00:06<00:00,  8.24it/s, mccloss - 0.4715, iou_score - 0.4424, accuracy - 0.9862, precision - 0.6009, recall - 0.6571, fscore - 0.5727]
# valid: 100%|██████████| 144/144 [00:04<00:00, 35.06it/s, mccloss - 0.8377, iou_score - 0.566, accuracy - 0.983, precision - 0.745, recall - 0.7609, fscore - 0.6008]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 30
# train: 100%|██████████| 56/56 [00:06<00:00,  8.49it/s, mccloss - 0.4475, iou_score - 0.4394, accuracy - 0.9864, precision - 0.5916, recall - 0.6893, fscore - 0.5759]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.17it/s, mccloss - 0.8382, iou_score - 0.5095, accuracy - 0.9815, precision - 0.6972, recall - 0.7587, fscore - 0.545]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 31
# train: 100%|██████████| 56/56 [00:07<00:00,  7.99it/s, mccloss - 0.4363, iou_score - 0.4621, accuracy - 0.9879, precision - 0.6195, recall - 0.6774, fscore - 0.59]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.96it/s, mccloss - 0.8371, iou_score - 0.532, accuracy - 0.9826, precision - 0.7208, recall - 0.7572, fscore - 0.5672]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 32
# train: 100%|██████████| 56/56 [00:06<00:00,  8.65it/s, mccloss - 0.441, iou_score - 0.4536, accuracy - 0.9876, precision - 0.6161, recall - 0.6535, fscore - 0.5866]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.95it/s, mccloss - 0.8411, iou_score - 0.5497, accuracy - 0.9831, precision - 0.7348, recall - 0.7553, fscore - 0.5837]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 33
# train: 100%|██████████| 56/56 [00:06<00:00,  8.80it/s, mccloss - 0.4431, iou_score - 0.4527, accuracy - 0.9878, precision - 0.6433, recall - 0.6669, fscore - 0.5828]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.88it/s, mccloss - 0.8409, iou_score - 0.5571, accuracy - 0.9834, precision - 0.7435, recall - 0.7537, fscore - 0.5911]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 34
# train: 100%|██████████| 56/56 [00:06<00:00,  8.67it/s, mccloss - 0.4393, iou_score - 0.4725, accuracy - 0.9872, precision - 0.6229, recall - 0.6881, fscore - 0.6035]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.01it/s, mccloss - 0.8377, iou_score - 0.5311, accuracy - 0.9821, precision - 0.7155, recall - 0.7615, fscore - 0.5662]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 35
# train: 100%|██████████| 56/56 [00:06<00:00,  8.47it/s, mccloss - 0.4483, iou_score - 0.4383, accuracy - 0.9866, precision - 0.6039, recall - 0.676, fscore - 0.5767]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.69it/s, mccloss - 0.838, iou_score - 0.5308, accuracy - 0.9823, precision - 0.7181, recall - 0.7581, fscore - 0.5661]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 36
# train: 100%|██████████| 56/56 [00:06<00:00,  8.33it/s, mccloss - 0.4274, iou_score - 0.4853, accuracy - 0.9875, precision - 0.6355, recall - 0.705, fscore - 0.617]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.40it/s, mccloss - 0.8383, iou_score - 0.5165, accuracy - 0.9817, precision - 0.6935, recall - 0.762, fscore - 0.5516]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 37
# train: 100%|██████████| 56/56 [00:06<00:00,  8.81it/s, mccloss - 0.441, iou_score - 0.4479, accuracy - 0.9862, precision - 0.6016, recall - 0.6996, fscore - 0.5797]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.25it/s, mccloss - 0.8376, iou_score - 0.4964, accuracy - 0.9811, precision - 0.6804, recall - 0.7628, fscore - 0.5316]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 38
# train: 100%|██████████| 56/56 [00:06<00:00,  8.02it/s, mccloss - 0.4412, iou_score - 0.4681, accuracy - 0.9867, precision - 0.6079, recall - 0.6952, fscore - 0.6009]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.68it/s, mccloss - 0.8372, iou_score - 0.5248, accuracy - 0.9824, precision - 0.7115, recall - 0.7589, fscore - 0.5599]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 39
# train: 100%|██████████| 56/56 [00:06<00:00,  8.58it/s, mccloss - 0.447, iou_score - 0.4696, accuracy - 0.9875, precision - 0.6358, recall - 0.6731, fscore - 0.5962]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.41it/s, mccloss - 0.8381, iou_score - 0.4958, accuracy - 0.9812, precision - 0.6858, recall - 0.7566, fscore - 0.5312]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 40
# train: 100%|██████████| 56/56 [00:06<00:00,  8.79it/s, mccloss - 0.4245, iou_score - 0.4869, accuracy - 0.9874, precision - 0.6422, recall - 0.6978, fscore - 0.6213]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.88it/s, mccloss - 0.8372, iou_score - 0.5318, accuracy - 0.9823, precision - 0.7185, recall - 0.7591, fscore - 0.567]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 41
# train: 100%|██████████| 56/56 [00:06<00:00,  8.84it/s, mccloss - 0.4225, iou_score - 0.4868, accuracy - 0.9875, precision - 0.6386, recall - 0.707, fscore - 0.6206]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.77it/s, mccloss - 0.8374, iou_score - 0.5174, accuracy - 0.9816, precision - 0.7021, recall - 0.7616, fscore - 0.5526]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 42
# train: 100%|██████████| 56/56 [00:06<00:00,  9.26it/s, mccloss - 0.4365, iou_score - 0.4748, accuracy - 0.9874, precision - 0.6239, recall - 0.6884, fscore - 0.6044]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.33it/s, mccloss - 0.8374, iou_score - 0.5176, accuracy - 0.9814, precision - 0.7048, recall - 0.7591, fscore - 0.5528]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 43
# train: 100%|██████████| 56/56 [00:06<00:00,  8.16it/s, mccloss - 0.4381, iou_score - 0.4787, accuracy - 0.9875, precision - 0.6295, recall - 0.6827, fscore - 0.6051]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.44it/s, mccloss - 0.8372, iou_score - 0.5108, accuracy - 0.9814, precision - 0.6992, recall - 0.7581, fscore - 0.5461]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 44
# train: 100%|██████████| 56/56 [00:06<00:00,  8.87it/s, mccloss - 0.424, iou_score - 0.4657, accuracy - 0.9873, precision - 0.6253, recall - 0.7021, fscore - 0.6024]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.00it/s, mccloss - 0.8397, iou_score - 0.5437, accuracy - 0.9826, precision - 0.7298, recall - 0.7563, fscore - 0.5783]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 45
# train: 100%|██████████| 56/56 [00:06<00:00,  8.33it/s, mccloss - 0.4193, iou_score - 0.4733, accuracy - 0.9875, precision - 0.6213, recall - 0.7121, fscore - 0.6056]
# valid: 100%|██████████| 144/144 [00:04<00:00, 34.16it/s, mccloss - 0.8384, iou_score - 0.5306, accuracy - 0.9824, precision - 0.7178, recall - 0.7569, fscore - 0.5657]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
# Epoch: 46
# train: 100%|██████████| 56/56 [00:06<00:00,  8.04it/s, mccloss - 0.4228, iou_score - 0.4856, accuracy - 0.9873, precision - 0.6319, recall - 0.7109, fscore - 0.6197]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.88it/s, mccloss - 0.8391, iou_score - 0.537, accuracy - 0.9824, precision - 0.7226, recall - 0.7576, fscore - 0.5718]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 47
# train: 100%|██████████| 56/56 [00:06<00:00,  8.25it/s, mccloss - 0.4384, iou_score - 0.4548, accuracy - 0.9872, precision - 0.5993, recall - 0.6923, fscore - 0.5852]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.62it/s, mccloss - 0.8382, iou_score - 0.5167, accuracy - 0.9822, precision - 0.705, recall - 0.7567, fscore - 0.552]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 48
# train: 100%|██████████| 56/56 [00:06<00:00,  8.86it/s, mccloss - 0.43, iou_score - 0.4638, accuracy - 0.9871, precision - 0.6133, recall - 0.6973, fscore - 0.5953]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.96it/s, mccloss - 0.8406, iou_score - 0.55, accuracy - 0.9829, precision - 0.7413, recall - 0.7564, fscore - 0.5841]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 49
# train: 100%|██████████| 56/56 [00:06<00:00,  8.03it/s, mccloss - 0.434, iou_score - 0.4577, accuracy - 0.9873, precision - 0.6183, recall - 0.6968, fscore - 0.5901]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.86it/s, mccloss - 0.8375, iou_score - 0.5102, accuracy - 0.9815, precision - 0.695, recall - 0.7615, fscore - 0.5456]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 50
# train: 100%|██████████| 56/56 [00:06<00:00,  8.39it/s, mccloss - 0.4343, iou_score - 0.4586, accuracy - 0.9872, precision - 0.6205, recall - 0.688, fscore - 0.5902]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.96it/s, mccloss - 0.8393, iou_score - 0.5367, accuracy - 0.9822, precision - 0.7214, recall - 0.7588, fscore - 0.5715]
# No improvement in 5 epochs. Model not saved.
#
# Epoch: 51
# train: 100%|██████████| 56/56 [00:06<00:00,  8.58it/s, mccloss - 0.4379, iou_score - 0.4624, accuracy - 0.9871, precision - 0.6201, recall - 0.6694, fscore - 0.5879]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.01it/s, mccloss - 0.8378, iou_score - 0.5243, accuracy - 0.9821, precision - 0.7095, recall - 0.7598, fscore - 0.5593]
# No improvement in 6 epochs. Model not saved.
#
# Epoch: 52
# train: 100%|██████████| 56/56 [00:06<00:00,  9.15it/s, mccloss - 0.4253, iou_score - 0.4888, accuracy - 0.9876, precision - 0.6616, recall - 0.6825, fscore - 0.6202]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.75it/s, mccloss - 0.8389, iou_score - 0.5302, accuracy - 0.9824, precision - 0.7151, recall - 0.759, fscore - 0.5652]
# No improvement in 7 epochs. Model not saved.
#
# Epoch: 53
# train: 100%|██████████| 56/56 [00:06<00:00,  8.47it/s, mccloss - 0.4316, iou_score - 0.4629, accuracy - 0.9877, precision - 0.6104, recall - 0.6921, fscore - 0.5929]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.31it/s, mccloss - 0.841, iou_score - 0.5427, accuracy - 0.9829, precision - 0.7347, recall - 0.7552, fscore - 0.5767]
# No improvement in 8 epochs. Model not saved.
#
# Epoch: 54
# train: 100%|██████████| 56/56 [00:06<00:00,  8.17it/s, mccloss - 0.4369, iou_score - 0.4562, accuracy - 0.9875, precision - 0.6373, recall - 0.6764, fscore - 0.587]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.89it/s, mccloss - 0.8381, iou_score - 0.5239, accuracy - 0.9821, precision - 0.7095, recall - 0.7594, fscore - 0.559]
# No improvement in 9 epochs. Model not saved.
#
# Epoch: 55
# train: 100%|██████████| 56/56 [00:06<00:00,  8.13it/s, mccloss - 0.417, iou_score - 0.5026, accuracy - 0.9878, precision - 0.647, recall - 0.7076, fscore - 0.6288]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.41it/s, mccloss - 0.8402, iou_score - 0.5717, accuracy - 0.9838, precision - 0.7646, recall - 0.7539, fscore - 0.6055]
# No improvement in 10 epochs. Model not saved.
#
# Epoch: 56
# train: 100%|██████████| 56/56 [00:06<00:00,  8.39it/s, mccloss - 0.427, iou_score - 0.4814, accuracy - 0.9875, precision - 0.633, recall - 0.7006, fscore - 0.6151]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.55it/s, mccloss - 0.8389, iou_score - 0.5373, accuracy - 0.9827, precision - 0.7237, recall - 0.757, fscore - 0.5722]
# No improvement in 11 epochs. Model not saved.
#
# Epoch: 57
# train: 100%|██████████| 56/56 [00:06<00:00,  8.84it/s, mccloss - 0.4154, iou_score - 0.5021, accuracy - 0.9877, precision - 0.6589, recall - 0.6987, fscore - 0.6311]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.81it/s, mccloss - 0.8388, iou_score - 0.5159, accuracy - 0.9818, precision - 0.7041, recall - 0.7567, fscore - 0.5514]
# No improvement in 12 epochs. Model not saved.
#
# Epoch: 58
# train: 100%|██████████| 56/56 [00:06<00:00,  8.21it/s, mccloss - 0.4279, iou_score - 0.4832, accuracy - 0.9878, precision - 0.6587, recall - 0.684, fscore - 0.6169]
# valid: 100%|██████████| 144/144 [00:04<00:00, 33.54it/s, mccloss - 0.8387, iou_score - 0.5159, accuracy - 0.9813, precision - 0.7049, recall - 0.7565, fscore - 0.5514]
# No improvement in 13 epochs. Model not saved.
#
# Epoch: 59
# train: 100%|██████████| 56/56 [00:07<00:00,  7.68it/s, mccloss - 0.4169, iou_score - 0.4914, accuracy - 0.9875, precision - 0.6319, recall - 0.7163, fscore - 0.6257]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.19it/s, mccloss - 0.8405, iou_score - 0.5505, accuracy - 0.9834, precision - 0.7435, recall - 0.7539, fscore - 0.5844]
# No improvement in 14 epochs. Model not saved.
#
# Epoch: 60
# train: 100%|██████████| 56/56 [00:06<00:00,  8.54it/s, mccloss - 0.4188, iou_score - 0.4936, accuracy - 0.9878, precision - 0.6466, recall - 0.7044, fscore - 0.6257]
# valid: 100%|██████████| 144/144 [00:04<00:00, 32.48it/s, mccloss - 0.84, iou_score - 0.5364, accuracy - 0.9827, precision - 0.7236, recall - 0.7547, fscore - 0.571]
# No improvement in 15 epochs. Model not saved.
# Decrease decoder learning rate by factor of 10
#
#
# ----------------------------------------------------------
# ['rgb', 'tpi', 'shade', 'ndvi', 'dsm']
#
# Epoch: 1
# train: 100%|██████████| 56/56 [00:06<00:00,  8.77it/s, mccloss - 0.9253, iou_score - 0.05722, accuracy - 0.6855, precision - 0.05802, recall - 0.8326, fscore - 0.1053]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.47it/s, mccloss - 0.9541, iou_score - 0.05142, accuracy - 0.8766, precision - 0.05431, recall - 0.8392, fscore - 0.08657]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 56/56 [00:06<00:00,  8.07it/s, mccloss - 0.8646, iou_score - 0.09022, accuracy - 0.798, precision - 0.0913, recall - 0.9376, fscore - 0.1607]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.55it/s, mccloss - 0.9232, iou_score - 0.07369, accuracy - 0.9, precision - 0.07693, recall - 0.8997, fscore - 0.1171]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 56/56 [00:06<00:00,  8.24it/s, mccloss - 0.8289, iou_score - 0.1205, accuracy - 0.8487, precision - 0.1219, recall - 0.942, fscore - 0.2071]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.65it/s, mccloss - 0.9142, iou_score - 0.1025, accuracy - 0.9612, precision - 0.1238, recall - 0.8442, fscore - 0.1501]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 56/56 [00:07<00:00,  7.60it/s, mccloss - 0.797, iou_score - 0.161, accuracy - 0.8912, precision - 0.1645, recall - 0.922, fscore - 0.2652]
# valid: 100%|██████████| 144/144 [00:05<00:00, 26.61it/s, mccloss - 0.9074, iou_score - 0.06283, accuracy - 0.8782, precision - 0.06413, recall - 0.9248, fscore - 0.1044]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 5
# train: 100%|██████████| 56/56 [00:06<00:00,  8.42it/s, mccloss - 0.7706, iou_score - 0.1901, accuracy - 0.9148, precision - 0.1956, recall - 0.9318, fscore - 0.3048]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.93it/s, mccloss - 0.8935, iou_score - 0.3324, accuracy - 0.9376, precision - 0.3689, recall - 0.896, fscore - 0.3783]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 56/56 [00:07<00:00,  7.92it/s, mccloss - 0.7472, iou_score - 0.1936, accuracy - 0.9198, precision - 0.2005, recall - 0.9156, fscore - 0.3091]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.30it/s, mccloss - 0.8845, iou_score - 0.394, accuracy - 0.9255, precision - 0.4552, recall - 0.8979, fscore - 0.4391]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 56/56 [00:07<00:00,  7.89it/s, mccloss - 0.707, iou_score - 0.254, accuracy - 0.9444, precision - 0.2667, recall - 0.8863, fscore - 0.3821]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.01it/s, mccloss - 0.8761, iou_score - 0.5467, accuracy - 0.9797, precision - 0.6943, recall - 0.802, fscore - 0.5881]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 56/56 [00:06<00:00,  8.32it/s, mccloss - 0.6579, iou_score - 0.3053, accuracy - 0.9592, precision - 0.3275, recall - 0.8625, fscore - 0.4449]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.16it/s, mccloss - 0.8576, iou_score - 0.4278, accuracy - 0.9555, precision - 0.4771, recall - 0.8837, fscore - 0.4795]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 9
# train: 100%|██████████| 56/56 [00:06<00:00,  8.47it/s, mccloss - 0.6175, iou_score - 0.3283, accuracy - 0.9632, precision - 0.3551, recall - 0.8778, fscore - 0.4676]
# valid: 100%|██████████| 144/144 [00:04<00:00, 31.32it/s, mccloss - 0.8376, iou_score - 0.5357, accuracy - 0.9667, precision - 0.6022, recall - 0.8837, fscore - 0.5872]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 10
# train: 100%|██████████| 56/56 [00:06<00:00,  8.22it/s, mccloss - 0.6058, iou_score - 0.3167, accuracy - 0.9635, precision - 0.3523, recall - 0.837, fscore - 0.4572]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.20it/s, mccloss - 0.8733, iou_score - 0.4531, accuracy - 0.9681, precision - 0.5926, recall - 0.7839, fscore - 0.4936]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 11
# train: 100%|██████████| 56/56 [00:06<00:00,  8.75it/s, mccloss - 0.6153, iou_score - 0.2946, accuracy - 0.9624, precision - 0.3361, recall - 0.7946, fscore - 0.4278]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.09it/s, mccloss - 0.8152, iou_score - 0.6374, accuracy - 0.9857, precision - 0.7593, recall - 0.8223, fscore - 0.6853]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 56/56 [00:06<00:00,  8.58it/s, mccloss - 0.5453, iou_score - 0.3622, accuracy - 0.971, precision - 0.4111, recall - 0.824, fscore - 0.5054]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.75it/s, mccloss - 0.842, iou_score - 0.6483, accuracy - 0.9879, precision - 0.8454, recall - 0.752, fscore - 0.6888]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 56/56 [00:06<00:00,  8.13it/s, mccloss - 0.5159, iou_score - 0.3798, accuracy - 0.9736, precision - 0.4286, recall - 0.8442, fscore - 0.5221]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.60it/s, mccloss - 0.8155, iou_score - 0.2991, accuracy - 0.9583, precision - 0.3275, recall - 0.8795, fscore - 0.3538]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 14
# train: 100%|██████████| 56/56 [00:07<00:00,  7.87it/s, mccloss - 0.522, iou_score - 0.388, accuracy - 0.9763, precision - 0.4653, recall - 0.7709, fscore - 0.5233]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.72it/s, mccloss - 0.8512, iou_score - 0.6857, accuracy - 0.9892, precision - 0.926, recall - 0.7265, fscore - 0.7154]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 56/56 [00:07<00:00,  7.98it/s, mccloss - 0.5058, iou_score - 0.3779, accuracy - 0.9737, precision - 0.4359, recall - 0.8013, fscore - 0.517]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.71it/s, mccloss - 0.8351, iou_score - 0.6891, accuracy - 0.989, precision - 0.9177, recall - 0.7401, fscore - 0.7222]
# Model saved!
# Decrease decoder learning rate by factor of 10
#
# Epoch: 16
# train: 100%|██████████| 56/56 [00:06<00:00,  8.39it/s, mccloss - 0.494, iou_score - 0.3955, accuracy - 0.9772, precision - 0.4764, recall - 0.7737, fscore - 0.5351]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.39it/s, mccloss - 0.7842, iou_score - 0.6034, accuracy - 0.9811, precision - 0.6916, recall - 0.8637, fscore - 0.6529]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 17
# train: 100%|██████████| 56/56 [00:06<00:00,  8.54it/s, mccloss - 0.4905, iou_score - 0.399, accuracy - 0.9777, precision - 0.4765, recall - 0.7876, fscore - 0.5382]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.77it/s, mccloss - 0.7852, iou_score - 0.6938, accuracy - 0.9868, precision - 0.8213, recall - 0.8282, fscore - 0.7403]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 56/56 [00:06<00:00,  8.16it/s, mccloss - 0.471, iou_score - 0.4187, accuracy - 0.979, precision - 0.4904, recall - 0.8041, fscore - 0.5581]
# valid: 100%|██████████| 144/144 [00:04<00:00, 30.30it/s, mccloss - 0.7811, iou_score - 0.6738, accuracy - 0.9852, precision - 0.7748, recall - 0.8511, fscore - 0.7217]
# No improvement in 1 epochs. Model not saved.
#
# Epoch: 19
# train: 100%|██████████| 56/56 [00:06<00:00,  8.05it/s, mccloss - 0.4705, iou_score - 0.4168, accuracy - 0.9789, precision - 0.4981, recall - 0.798, fscore - 0.556]
# valid: 100%|██████████| 144/144 [00:05<00:00, 27.86it/s, mccloss - 0.7827, iou_score - 0.6328, accuracy - 0.9826, precision - 0.714, recall - 0.8613, fscore - 0.6827]
# No improvement in 2 epochs. Model not saved.
#
# Epoch: 20
# train: 100%|██████████| 56/56 [00:06<00:00,  8.23it/s, mccloss - 0.4642, iou_score - 0.425, accuracy - 0.9793, precision - 0.5035, recall - 0.8025, fscore - 0.5638]
# valid: 100%|██████████| 144/144 [00:04<00:00, 29.10it/s, mccloss - 0.7762, iou_score - 0.6787, accuracy - 0.9856, precision - 0.7719, recall - 0.8538, fscore - 0.7265]
# No improvement in 3 epochs. Model not saved.
#
# Epoch: 21
# train: 100%|██████████| 56/56 [00:06<00:00,  8.67it/s, mccloss - 0.4496, iou_score - 0.4408, accuracy - 0.9807, precision - 0.5203, recall - 0.8218, fscore - 0.5806]
# valid: 100%|██████████| 144/144 [00:05<00:00, 28.28it/s, mccloss - 0.7744, iou_score - 0.6642, accuracy - 0.9853, precision - 0.7556, recall - 0.8558, fscore - 0.7135]
# No improvement in 4 epochs. Model not saved.
#
# Epoch: 22
# train: 100%|██████████| 56/56 [00:06<00:00,  8.26it/s, mccloss - 0.4722, iou_score - 0.4153, accuracy - 0.9795, precision - 0.4935, recall - 0.7839, fscore - 0.5554]
# valid: 100%|██████████| 144/144 [00:05<00:00, 26.40it/s, mccloss - 0.7707, iou_score - 0.6861, accuracy - 0.987, precision - 0.7828, recall - 0.8491, fscore - 0.7335]
# No improvement in 5 epochs. Model not saved.
# More than 5 epochs without validation improvement while learning rate <= 1e-5 and training improvement < 0.05...ending training

# %%
print('All processing complete!')
# Out:
# All processing complete!
